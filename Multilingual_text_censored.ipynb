# %%
# %%capture
# !pip install boto3
# !pip install Levenshtein
# !pip install python-Levenshtein
# !pip install azure-cognitiveservices-vision-computervision boto3
# !apt-get install -y tesseract-ocr
# !pip install pytesseract
# !pip install google-cloud-vision
# !pip install -qU langchain-google-genai

# %%
import os
import zipfile
import json
import random
import time
from azure.cognitiveservices.vision.computervision import ComputerVisionClient
from azure.cognitiveservices.vision.computervision.models import OperationStatusCodes
from msrest.authentication import CognitiveServicesCredentials
import requests
import boto3
from difflib import SequenceMatcher
import logging
import openai
from openai import OpenAI
import Levenshtein
import pytesseract
from PIL import Image
from langchain_google_genai import ChatGoogleGenerativeAI
import re

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
folder = "/content/drive/MyDrive/vision_datasets/ICDAR 2019 MLT"

# %% [markdown]
# The 10,000 images are ordered in the training set such that: each consecutive 1000 images contain text of one main language (and it may of course contain additional text from 1 or 2 other languages, all from the set of the 10 languages)
# 00001 - 01000:  Arabic
# 01001 - 02000:  English
# 02001 - 03000:  French
# 03001 - 04000:  Chinese
# 04001 - 05000:  German
# 05001 - 06000:  Korean
# 06001 - 07000:  Japanese
# 07001 - 08000:  Italian
# 08001 - 09000:  Bangla
# 09001 - 10000:  Hindi

# %%
# Language ranges
languages = {
    "Arabic": (1, 1000),
    "English": (1001, 2000),
    "French": (2001, 3000),
    "Chinese": (3001, 4000),
    "German": (4001, 5000),
    "Korean": (5001, 6000),
    "Japanese": (6001, 7000),
    "Italian": (7001, 8000),
    "Bangla": (8001, 9000),
    "Hindi": (9001, 10000),
}

# Maximum file size (1MB)
max_size = 1 * 1024 * 1024

# %%
indices = [0, 3, 5,6,9]

hard_languages = []
for i in indices:
    hard_languages.append(list(languages.keys())[i])

# %%
hard_languages
# Out:
# ['Arabic', 'Chinese', 'Korean', 'Japanese', 'Hindi']

# %%
image_paths_by_language = {}

# Loop over each language
for lang, (start, end) in languages.items():
    print(f"Processing {lang}...")


    # Generate file paths for the range
    all_files = [
        os.path.join(folder, f"tr_img_{i:05d}.jpg")
        for i in range(start, end + 1)
    ]

    # Filter files by size and existence
    valid_files = [
        file for file in all_files
        if os.path.exists(file) and os.path.getsize(file) < max_size
    ]

    # Take the first 50 images
    selected_files = valid_files[:50]

    # Copy files to the language folder
    image_paths_by_language[lang] = selected_files

print("Image paths by language dictionary created successfully.")
# Out:
# Processing Arabic...
# Processing English...
# Processing French...
# Processing Chinese...
# Processing German...
# Processing Korean...
# Processing Japanese...
# Processing Italian...
# Processing Bangla...
# Processing Hindi...
# Image paths by language dictionary created successfully.

# %%
list(languages.keys())[0:5]
# Out:
# ['Arabic', 'English', 'French', 'Chinese', 'German']

# %%
list(languages.keys())[5:10]
# Out:
# ['Korean', 'Japanese', 'Italian', 'Bangla', 'Hindi']

# %%
def estrai_parole_da_file(percorso_file):
    parole = []
    with open(percorso_file, 'r') as file:
        for riga in file:
            # Extract the last word or quoted word after the last comma
            match = re.search(r',\s*"?([^",]+)"?\s*$', riga.strip())
            if match:
                transcription = match.group(1)
                # Ignore transcriptions that are ###
                if transcription != "###":
                    parole.append(transcription)
    return parole

# %%
percorso_file = "/content/drive/MyDrive/vision_datasets/ICDAR 2019 MLT/tr_img_00001.txt"

# Estrazione delle parole
parole_estratte = estrai_parole_da_file(percorso_file)
print(parole_estratte)
# Out:
# ['CT', 'تليفون:٠١٣٨٩٠٤٠٦٦', 'Systems', 'Division', 'Okaz', 'Security', 'O', 'Telecom', 'HIKVISION', 'ViRDI', 'ZKSoftware', '8904066', 'Tel:013', 'عكاظ', 'للإتصالات', 'E-Guard', 'ELECTRONIC', 'GUARD', 'قسم', 'الأنظمة', 'الأمنية', 'C']

# %%
output_file = "/content/drive/MyDrive/image_paths_by_language.json"

# %%
# Save the dictionary to a JSON file
with open(output_file, "w") as f:
    json.dump(image_paths_by_language, f, indent=4)

print(f"Dictionary saved to {output_file}")
# Out:
# Dictionary saved to /content/drive/MyDrive/image_paths_by_language.json

# %%
with open(output_file, "r") as f:
    image_paths_by_language = json.load(f)

# %%
len(image_paths_by_language)
# Out:
# 10

# %%
image_paths_by_language.keys()
# Out:
# dict_keys(['Arabic', 'English', 'French', 'Chinese', 'German', 'Korean', 'Japanese', 'Italian', 'Bangla', 'Hindi'])

# %% [markdown]
# # LLM Initializitation

# %%
import os

if "GOOGLE_API_KEY" not in os.environ:
    os.environ["GOOGLE_API_KEY"] = GOOGLE_API_KEY

# %%
llm = ChatGoogleGenerativeAI(
    model="gemini-1.5-flash",
    temperature=0,
    max_tokens=None,
    timeout=None,
    max_retries=2
)

# %%
prompt_template='''You are an advanced language model specialized in text correction. You will receive text extracted from images using OCR (Optical Character Recognition) models. Your task is to identify and correct any misspelled words or inaccuracies while preserving the context and intended meaning of the text.
### Instructions:
1. Correct spelling errors: Replace any misspelled words with the correct ones.
2. Maintain context: Ensure that the corrected text aligns with the overall meaning and structure of the original input.
3. Handle OCR-specific errors:
   - Fix common OCR mistakes such as incorrect substitutions of similar-looking characters (e.g., "rn" misread as "m").
   - Handle mixed-case errors, such as "tHiS iS" to "This is."
4. Do not alter proper nouns, numbers, or special characters unless they are obviously incorrect.
5. Do not add or remove punctuations

Output the corrected text clearly and concisely.

### Example Inputs and Outputs:

**Input:**
Th1s 1s an exarnple of OCR t3xt.

**Output:**
This is an example of OCR text.

**Input:**
Th@ rn0del w1ll c0rrect err0rs.

**Output:**
The model will correct errors.

Focus on accuracy and consistency. Your goal is to produce clean and coherent text that closely resembles the intended content. Only output the corrected text and nothing else'''

# %%
from langchain_core.prompts import ChatPromptTemplate

prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            prompt_template,
        ),
        ("human", "{input}"),
    ]
)

# %%
from langchain_core.output_parsers.string import StrOutputParser

# %%
model=prompt|llm|StrOutputParser()

# %%
# Functions for Metrics
def calculate_levenshtein_accuracy(extracted_text, ground_truth):
    extracted_text = extracted_text.strip().lower()
    ground_truth = ground_truth.strip().lower()
    distance = Levenshtein.distance(extracted_text, ground_truth)
    max_length = max(len(extracted_text), len(ground_truth))
    return (1 - distance / max_length) * 100 if max_length > 0 else 0

def calculate_word_accuracy(expected_words, ocr_words):
    expected_set = set(word.lower() for word in expected_words)
    ocr_set = set(word.lower() for word in ocr_words)
    matching_words = expected_set & ocr_set
    return (len(matching_words) / len(expected_set)) * 100 if expected_set else 0

def calculate_character_error_rate(extracted_text, ground_truth):
    errors = Levenshtein.distance(extracted_text, ground_truth)
    total_chars = len(ground_truth)
    return (errors / total_chars) * 100 if total_chars > 0 else 0

# Evaluation Pipeline
def evaluate_ocr(ocr_dict):
    """
    Evaluate OCR output against ground truth for each entry in a dictionary.

    Parameters:
        ocr_dict (dict): Dictionary with keys as image names and values as OCR outputs.
        type: 'scene' o 'document'

    Returns:
        dict: A dictionary with image names as keys and evaluation metrics as values.
    """
    evaluation_results = {}

    for image_name, ocr_output in ocr_dict.items():

        #ground_truth_file = f"{folder}/{os.path.splitext(image_name)[0]}.json"
        ground_truth_file=os.path.join(folder, image_name.rsplit('.', 1)[0] + '.txt')

      #output_json_path = os.path.join(folder, image_name.rsplit('.', 1)[0] + '_ocr.json')



        # Assuming ground truth JSON has a key "text" containing the expected output
        #ground_truth = " ".join(item["text"] for item in ground_truth_data if "text" in item)

        ground_truth_words = estrai_parole_da_file(ground_truth_file)
        ground_truth_text=" ".join(item for item in ground_truth_words)
        lev_acc_baseline = calculate_levenshtein_accuracy(ocr_output, ground_truth_text)
        word_acc_baseline = calculate_word_accuracy(ground_truth_words, ocr_output.split())
        cer_baseline = calculate_character_error_rate(ocr_output, ground_truth_text)

        #LLM
        llm_output=model.invoke({'input':ocr_output})
        time.sleep(5)#Con il piano gratuito, possiamo fare solo 15 run al minuto
        lev_acc_llm = calculate_levenshtein_accuracy(llm_output, ground_truth_text)
        word_acc_llm = calculate_word_accuracy(ground_truth_words, llm_output.split())
        cer_llm = calculate_character_error_rate(llm_output, ground_truth_text)



        # Store the results in the evaluation dictionary
        evaluation_results[os.path.splitext(image_name)[0]] = {
            "Levenshtein Accuracy": lev_acc_baseline,
            "Word Accuracy": word_acc_baseline,
            "Character Error Rate": cer_baseline,
            "Levenshtein Accuracy LLM": lev_acc_llm,
            "Word Accuracy LLM": word_acc_llm,
            "Character Error Rate LLM": cer_llm

        }
    return evaluation_results

# %% [markdown]
# ## AZURE

# %%
subscription_key = AZURE_API_KEY
endpoint = "https://patrikbaldon.cognitiveservices.azure.com/"
computervision_client = ComputerVisionClient(endpoint, CognitiveServicesCredentials(subscription_key))

# %%
azure_extraction = {}

# Funzione per estrarre testo e aggiungerlo al dizionario
def extract_text_azure(image_path):
    with open(image_path, "rb") as image_file:
        read_response = computervision_client.read_in_stream(image_file, raw=True)
        operation_location = read_response.headers["Operation-Location"]
        operation_id = operation_location.split("/")[-1]

        # Attendi il completamento
        while True:
            result = computervision_client.get_read_result(operation_id)
            if result.status not in ['notStarted', 'running']:
                break
            time.sleep(1)

        # Estrai il testo
        extracted_text = ""
        if result.status == OperationStatusCodes.succeeded:
            for page in result.analyze_result.read_results:
                for line in page.lines:
                    extracted_text += line.text + " "

        # Salva nel dizionario
        azure_extraction[os.path.basename(image_path)] = extracted_text.strip()

# %%
#Azure_Evaluation = {}
for lang in list(languages.keys())[5:10]:
  images_paths = image_paths_by_language[lang]
  azure_extraction = {}
  print(f"Extracting text from {lang} images")
  for image_path in images_paths:
    extract_text_azure(image_path)
  print(f"Evaluating model on {lang} images")
  Azure_Evaluation[lang] = evaluate_ocr(azure_extraction)
# Out:
# Extracting text from Korean images
# Evaluating model on Korean images
# Extracting text from Japanese images
# Evaluating model on Japanese images
# Extracting text from Italian images
# Evaluating model on Italian images
# Extracting text from Bangla images
# Evaluating model on Bangla images
# Extracting text from Hindi images
# Evaluating model on Hindi images

# %%
len(Azure_Evaluation)
# Out:
# 10

# %%
len(Azure_Evaluation['German'])
# Out:
# 50

# %%
output_file = "/content/drive/MyDrive/Azure_Evaluations.json"

# Save the dictionary to a JSON file
with open(output_file, "w") as f:
    json.dump(Azure_Evaluation, f, indent=4)

print(f"Dictionary saved to {output_file}")
# Out:
# Dictionary saved to /content/drive/MyDrive/Azure_Evaluations.json

# %%
azure_file="/content/drive/MyDrive/Azure_Evaluations.json"
with open(azure_file, "r") as f:
    Azure_Evaluation = json.load(f)

# %%
keys = list(Azure_Evaluation['Arabic'].keys())
values = list(Azure_Evaluation['Arabic'].values())

print(f"First record:\nKey: {keys[0]}\nValue: {values[0]}")
# Out:
# First record:
# Key: tr_img_00001
# Value: {'Levenshtein Accuracy': 26.630434782608692, 'Word Accuracy': 77.27272727272727, 'Character Error Rate': 82.53012048192771, 'Levenshtein Accuracy LLM': 28.260869565217394, 'Word Accuracy LLM': 77.27272727272727, 'Character Error Rate LLM': 80.72289156626506}

# %% [markdown]
# # AWS

# %%
file_names={}
for lang in languages.keys():
  file_names[lang] = [os.path.splitext(os.path.basename(path))[0] for path in images_paths_by_language[lang]]
print(file_names['Arabic'][0:10])

# %%
def list_images_in_folder(bucket,language):
    session = boto3.Session(
        aws_access_key_id=AWS_API_KEY,
        aws_secret_access_key=AWS_SECRET,
        region_name='us-east-1'
    )
    s3 = session.client('s3')
    response = s3.list_objects_v2(Bucket=bucket, Prefix="ICDAR 2019 MLT/")

    # Dimensione massima in bytes (1 MB)
    max_size = 1 * 1024 * 1024  # 1 MB

    # Ottieni e ordina le immagini per nome
    sorted_objects = sorted(
        [obj for obj in response.get('Contents', []) if obj['Key'].endswith(('.jpg', '.png', '.jpeg'))],
        key=lambda x: x['Key']
    )

    # Filtra immagini per dimensione
    return [
        (obj['Key'], obj['Key'].split('/')[-1].split('.')[0])
        for obj in sorted_objects
        if (obj['Key'].split('/')[-1].split('.')[0] in file_names[language])
    ]

# %%
def extract_text_textract(bucket, image_name):
    session = boto3.Session(
        aws_access_key_id=AWS_API_KEY,
        aws_secret_access_key=AWS_SECRET,
        region_name='us-east-1'
    )
    textract = session.client('textract')
    response = textract.detect_document_text(
        Document={'S3Object': {'Bucket': bucket, 'Name': image_name}}
    )
    extracted_text = []
    for block in response['Blocks']:
        if block['BlockType'] == 'LINE':
            extracted_text.append(block['Text'])
    return " ".join(extracted_text)

# %%
# Configurazione AWS
region_name = "us-east-1"
bucket_name = "patriksbucket"

aws_extraction = {}


files = list_images_in_folder(bucket_name,lang)


for path, image_name in files[10:20]:
  # Estrai testo dall'immagine
  aws_extraction[image_name] = extract_text_textract(bucket_name, path)

# %%
region_name = "us-east-1"
bucket_name = "patriksbucket"

Aws_Evaluation = {}
for lang in languages.keys():
  images_paths = list_images_in_folder(bucket_name,lang)
  aws_extraction = {}
  print(f"Extracting text from {lang} images")
  for path, image_name in images_paths:
    aws_extraction[image_name] = extract_text_textract(bucket_name, path)
  print(f"Evaluating model on {lang} images")
  Aws_Evaluation[lang] = evaluate_ocr(aws_extraction)

# %%
Aws_Evaluation = evaluate_ocr(aws_extraction,'document')

# %%
keys = list(Aws_Evaluation['Arabic'].keys())
values = list(Aws_Evaluation['Arabic'].values())

print(f"First record:\nKey: {keys[0]}\nValue: {values[0]}")
# Out:
# First record:
# Key: tr_img_00011
# Value: {'Levenshtein Accuracy': 36.92307692307693, 'Word Accuracy': 33.33333333333333, 'Character Error Rate': 63.07692307692307, 'Levenshtein Accuracy LLM': 36.92307692307693, 'Word Accuracy LLM': 25.0, 'Character Error Rate LLM': 63.07692307692307}

# %%
aws_extraction['tr_img_00011']
# Out:
# 'asijasi will Fell Citron Violette Lavande 5789'

# %% [markdown]
# # OCR_SPACE

# %%
#folder="/content/test_data/test"

# %%
API_KEY = OCR_SPACE_API_KEY
ocrspace_extraction = {}

# %%
def ocr_space_file(image_path, output_path=None, overlay=False, api_key=None, language='eng'):
    """
    OCR.space API request with a local file, optionally saving results as JSON.

    Parameters:
        image_path (str): Path to the file.
        output_path (str, optional): Path to save the resulting JSON file.
        overlay (bool, optional): Include OCR overlay in the response.
        api_key (str): Your OCR.space API key.
        language (str): Language code for OCR.

    Returns:
        str: Extracted text from the image or None if an error occurred.
    """
    payload = {
        'isOverlayRequired': overlay,
        'apikey': api_key,
        'language': language,
        'OCREngine': 2
    }

    try:
        # Open the image file in binary mode
        with open(image_path, 'rb') as f:
            r = requests.post(
                'https://api.ocr.space/parse/image',
                files={os.path.basename(image_path): f},
                data=payload,
            )
        result = r.json()

        # Check if the response contains errors
        #if result.get("IsErroredOnProcessing", False):
        #    print(f"Error processing {image_path}: {result.get('ErrorMessage', 'Unknown error')}")
        #    return None

        # Extract the text
        return result["ParsedResults"][0]["ParsedText"].replace('\n', ' ')

    except Exception as e:
        print(f"Exception occurred for {image_path}: {e}")
        return None

# %%
hard_languages[3:5]
# Out:
# ['Japanese', 'Hindi']

# %%
output_file = "/content/drive/MyDrive/ocrspace_Evaluations.json"
with open(output_file, "r") as f:
    OcrSpace_Evaluation = json.load(f)

# %%
len(OcrSpace_Evaluation)
# Out:
# 3

# %%
#OcrSpace_Evaluation = {}
for lang in hard_languages[3:5]:
  images_paths = image_paths_by_language[lang]
  ocrspace_extraction = {}
  print(f"Extracting text from {lang} images")
  for image_path in images_paths:
    text=ocr_space_file(image_path, api_key=OCR_SPACE_KEY)
    time.sleep(2)
    if text:
      ocrspace_extraction[os.path.basename(image_path)] =text

  print(f"Evaluating model on {lang} images")
  OcrSpace_Evaluation[lang] = evaluate_ocr(ocrspace_extraction)
# Out:
# Extracting text from Japanese images
# Exception occurred for /content/drive/MyDrive/vision_datasets/ICDAR 2019 MLT/tr_img_06001.jpg: list index out of range
# Exception occurred for /content/drive/MyDrive/vision_datasets/ICDAR 2019 MLT/tr_img_06004.jpg: list index out of range
# Exception occurred for /content/drive/MyDrive/vision_datasets/ICDAR 2019 MLT/tr_img_06006.jpg: Expecting value: line 1 column 1 (char 0)
# Exception occurred for /content/drive/MyDrive/vision_datasets/ICDAR 2019 MLT/tr_img_06013.jpg: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# Exception occurred for /content/drive/MyDrive/vision_datasets/ICDAR 2019 MLT/tr_img_06015.jpg: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# Exception occurred for /content/drive/MyDrive/vision_datasets/ICDAR 2019 MLT/tr_img_06016.jpg: HTTPSConnectionPool(host='api.ocr.space', port=443): Max retries exceeded with url: /parse/image (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f985874d850>, 'Connection to api.ocr.space timed out. (connect timeout=None)'))
# Exception occurred for /content/drive/MyDrive/vision_datasets/ICDAR 2019 MLT/tr_img_06019.jpg: list index out of range
# Exception occurred for /content/drive/MyDrive/vision_datasets/ICDAR 2019 MLT/tr_img_06021.jpg: string indices must be integers, not 'str'
# Evaluating model on Japanese images
# Extracting text from Hindi images
# Evaluating model on Hindi images

# %%
output_file = "/content/drive/MyDrive/ocrspace_Evaluations.json"

# Save the dictionary to a JSON file
with open(output_file, "w") as f:
    json.dump(OcrSpace_Evaluation, f, indent=4)

print(f"Dictionary saved to {output_file}")
# Out:
# Dictionary saved to /content/drive/MyDrive/ocrspace_Evaluations.json

# %%
len(OcrSpace_Evaluation)
# Out:
# 5

# %%
keys = list(OcrSpace_Evaluation['Arabic'].keys())
values = list(OcrSpace_Evaluation['Arabic'].values())

print(f"First record:\nKey: {keys[0]}\nValue: {values[0]}")
# Out:
# First record:
# Key: tr_img_00011
# Value: {'Levenshtein Accuracy': 38.46153846153846, 'Word Accuracy': 91.66666666666666, 'Character Error Rate': 61.53846153846154, 'Levenshtein Accuracy LLM': 37.878787878787875, 'Word Accuracy LLM': 91.66666666666666, 'Character Error Rate LLM': 63.07692307692307}

# %%
ocrspace_extraction['tr_img_00011.jpg']
# Out:
# 'Fell الفل الليمون Citron البنفسج Violette 5 7 الخزامة Lavande 8 9'

# %% [markdown]
# # GOOGLE CLOUD VISION API

# %%
cloudvisionapikey = CLOUD_VISION_API_KEY
cloudvision_extraction = {}

# %%
from google.cloud import vision
from google.auth.transport.requests import Request
from google.auth.credentials import AnonymousCredentials
import requests
import base64 # Import base64

def detect_text(image_path):
    """
    Detect text in an image using the Vision API with an API key.

    Args:
        api_key (str): Your Google Cloud Vision API key.
        image_path (str): Path to the image file.

    Returns:
        str: Detected text.
    """
    # Read the image file
    with open(image_path, "rb") as image_file:
        image_content = image_file.read()

    # Encode image content to base64
    image_content_base64 = base64.b64encode(image_content).decode('utf-8')

    # Create the request payload
    url = f"https://vision.googleapis.com/v1/images:annotate?key={cloudvisionapikey}"
    headers = {"Content-Type": "application/json"}
    payload = {
        "requests": [
            {
                "image": {"content": image_content_base64}, # Use base64 encoded content
                "features": [{"type": "TEXT_DETECTION"}]
            }
        ]
    }

    # Send the request
    response = requests.post(url, json=payload, headers=headers)
    response.raise_for_status()

    # Parse the response
    result = response.json()
    if "responses" in result and "textAnnotations" in result["responses"][0]:
        detected_text = result["responses"][0]["textAnnotations"][0]["description"]
        return detected_text
    else:
        return "No text detected."

# %%
OcrCloudVision_Evaluation = {}
for lang in hard_languages:
  images_paths = image_paths_by_language[lang]
  cloudvision_extraction = {}
  print(f"Extracting text from {lang} images")
  for image_path in images_paths:
    cloudvision_extraction[os.path.basename(image_path)] = detect_text(image_path)
  print(f"Evaluating model on {lang} images")
  OcrCloudVision_Evaluation[lang] = evaluate_ocr(cloudvision_extraction)
# Out:
# Extracting text from Arabic images
# Evaluating model on Arabic images
# Extracting text from Chinese images
# Evaluating model on Chinese images
# Extracting text from Korean images
# Evaluating model on Korean images
# Extracting text from Japanese images
# Evaluating model on Japanese images
# Extracting text from Hindi images
# Evaluating model on Hindi images

# %%
output_file = "/content/drive/MyDrive/Cloudvision_Evaluations.json"

# Save the dictionary to a JSON file
with open(output_file, "w") as f:
    json.dump(OcrCloudVision_Evaluation, f, indent=4)

print(f"Dictionary saved to {output_file}")
# Out:
# Dictionary saved to /content/drive/MyDrive/Cloudvision_Evaluations.json

# %%
cloud_file="/content/drive/MyDrive/Cloudvision_Evaluations.json"
with open(cloud_file, "r") as f:
    OcrCloudVision_Evaluation = json.load(f)

# %%
keys = list(OcrCloudVision_Evaluation['Arabic'].keys())
values = list(OcrCloudVision_Evaluation['Arabic'].values())

print(f"First record:\nKey: {keys[0]}\nValue: {values[0]}")
# Out:
# First record:
# Key: tr_img_00011
# Value: {'Levenshtein Accuracy': 27.692307692307693, 'Word Accuracy': 58.333333333333336, 'Character Error Rate': 72.3076923076923, 'Levenshtein Accuracy LLM': 27.692307692307693, 'Word Accuracy LLM': 58.333333333333336, 'Character Error Rate LLM': 72.3076923076923}

# %%
cloudvision_extraction['tr_img_00011.jpg']
# Out:
# 'Fell\nالفل\nالليمون\nCitron\nالبنفسج\nViolette\nالخزامة\nLavande\n789\n67'

# %% [markdown]
# # TESSERACT

# %%
tesseract_extraction = {}

# %%
print(pytesseract.get_languages(config=''))
# Out:
# ['eng', 'osd']

# %%
# Function to extract text using Tesseract OCR
def extract_text_tesseract(image_path):
  text = pytesseract.image_to_string(Image.open(image_path),lang='eng+ara')
  return text.strip()

# %%
for image_path in images_paths[10:20]:
  tesseract_extraction[os.path.basename(image_path)] = extract_text_tesseract(image_path)

# %%
Tesseract_Evaluation = evaluate_ocr(tesseract_extraction, 'document')

# %%
keys = list(Tesseract_Evaluation.keys())
values = list(Tesseract_Evaluation.values())

print(f"First record:\nKey: {keys[0]}\nValue: {values[0]}")
# Out:
# First record:
# Key: tr_img_00011
# Value: {'Levenshtein Accuracy': 0.0, 'Word Accuracy': 0.0, 'Character Error Rate': 100.0, 'Levenshtein Accuracy LLM': 13.846153846153841, 'Word Accuracy LLM': 0.0, 'Character Error Rate LLM': 87.6923076923077}

# %%
tesseract_extraction['tr_img_00011.jpg']
# Out:
# ''

# %% [markdown]
# # COMPARE THE EVALUATIONS

# %%
def calculate_score(metrics, alpha, beta, gamma):

    lev_accuracy = metrics.get("Levenshtein Accuracy", 0)
    word_accuracy = metrics.get("Word Accuracy", 0)
    cer = metrics.get("Character Error Rate", 0)

    total_score = alpha * lev_accuracy + beta * word_accuracy - gamma * cer
    return total_score


def evaluate_all_metrics(evaluations, alpha, beta, gamma):

    best_api = None
    best_score = float('-inf')

    print("API Scores:\n")

    for api_name, image_metrics in evaluations.items():
        total_score = 0
        num_images = len(image_metrics)
        for image_name, metrics in image_metrics.items():
            total_score += calculate_score(metrics, alpha, beta, gamma)
        avg_score = total_score / num_images if num_images > 0 else 0

        print(f"{api_name} - Average Score: {avg_score:.2f}")

        if avg_score > best_score:
            best_score = avg_score
            best_api = api_name

    return best_api, best_score

# %%
# Esempio di dati delle metriche
evaluations = {
    "Azure OCR": Azure_Evaluation,
    #"AWS Textract": Aws_Evaluation,
    "OCR.space": OcrSpace_Evaluation,
    "Google Cloud Vision": OcrCloudVision_Evaluation,
    #"Tesseract": Tesseract_Evaluation
}

# Confronta le metriche per tutte le API
best_api, best_score = evaluate_all_metrics(evaluations, alpha=0.01, beta=1, gamma=0.01)
print(f"\nThe best OCR API is {best_api} with an average score of {best_score:.2f}.")
# Out:
# API Scores:
#
# Azure OCR - Average Score: 13.88
# AWS Textract - Average Score: -44.99
# OCR.space - Average Score: -1.28
# Google Cloud Vision - Average Score: 14.28
# Tesseract - Average Score: -119.28
#
# The best OCR API is Google Cloud Vision with an average score of 14.28.

# %% [markdown]
# # COMPARE THE EVALUATIONS

# %%
import pandas as pd

# %%
def calculate_score(metrics, alpha, beta, gamma):

    lev_accuracy = metrics.get("Levenshtein Accuracy", 0)
    word_accuracy = metrics.get("Word Accuracy", 0)
    cer = metrics.get("Character Error Rate", 0)

    total_score = alpha * lev_accuracy + beta * word_accuracy - gamma * cer
    return total_score

def calculate_score_llm(metrics, alpha, beta, gamma):

    lev_accuracy = metrics.get("Levenshtein Accuracy LLM", 0)
    word_accuracy = metrics.get("Word Accuracy LLM", 0)
    cer = metrics.get("Character Error Rate LLM", 0)

    total_score = alpha * lev_accuracy + beta * word_accuracy - gamma * cer
    return total_score


def evaluate_all_metrics(evaluations, alpha, beta, gamma):

    best_api = None
    best_score = float('-inf')
    results=[]

    print("API Scores:\n")

    for api_name, image_metrics in evaluations.items():
        total_score = 0
        total_score_llm = 0
        total_lev_accuracy = 0
        total_word_accuracy = 0
        total_cer = 0
        total_lev_accuracy_llm = 0
        total_word_accuracy_llm = 0
        total_cer_llm = 0
        num_images = len(image_metrics)
        for image_name, metrics in image_metrics.items():
            total_score += calculate_score(metrics, alpha, beta, gamma)
            total_score_llm += calculate_score_llm(metrics, alpha, beta, gamma)

            total_lev_accuracy += metrics.get("Levenshtein Accuracy", 0)
            total_word_accuracy += metrics.get("Word Accuracy", 0)
            total_cer += metrics.get("Character Error Rate", 0)

            total_lev_accuracy_llm += metrics.get("Levenshtein Accuracy LLM", 0)
            total_word_accuracy_llm += metrics.get("Word Accuracy LLM", 0)
            total_cer_llm += metrics.get("Character Error Rate LLM", 0)
        avg_score = total_score / num_images if num_images > 0 else 0
        avg_score_llm = total_score_llm / num_images if num_images > 0 else 0

        avg_lev_accuracy = total_lev_accuracy / num_images if num_images > 0 else 0
        avg_word_accuracy = total_word_accuracy / num_images if num_images > 0 else 0
        avg_cer = total_cer / num_images if num_images > 0 else 0

        avg_lev_accuracy_llm = total_lev_accuracy_llm / num_images if num_images > 0 else 0
        avg_word_accuracy_llm = total_word_accuracy_llm / num_images if num_images > 0 else 0
        avg_cer_llm = total_cer_llm / num_images if num_images > 0 else 0

        print(f"{api_name} - Average Score: {avg_score:.2f}, with LLM: {avg_score_llm:.2f}")

        results.append({
            "API Name": api_name,
            "Levenshtein Accuracy": avg_lev_accuracy,
            "Levenshtein Accuracy with LLM": avg_lev_accuracy_llm,
            "Word Accuracy": avg_word_accuracy,
            "Word Accuracy with LLM": avg_word_accuracy_llm,
            "Character Error Rate": avg_cer,
            "Character Error Rate with LLM": avg_cer_llm,
            "Average Score": avg_score,
            "Average Score with LLM": avg_score_llm
        })


        if avg_score > best_score:
            best_score = avg_score
            best_api = api_name


    df = pd.DataFrame(results)
    df.to_excel("multilingual_ocr_evaluation_results.xlsx", index=False)

    print("\nResults saved to excel file")
    return best_api, best_score

# %%
def evaluate_all_metrics(evaluations, alpha, beta, gamma, hard_languages):
    """
    Evaluates metrics for OCR APIs and generates Excel files for each hard language.

    Args:
        evaluations (dict): A dictionary where keys are API names, and values are dictionaries with
                            languages as keys and evaluation results (metrics for each image).
        alpha (float): Weight for Levenshtein Accuracy.
        beta (float): Weight for Word Accuracy.
        gamma (float): Weight for Character Error Rate.
        hard_languages (list): List of hard languages to process.

    Returns:
        dict: A summary of best API and score for each hard language.
    """
    best_api_per_language = {}

    for language in hard_languages:
        results = []
        best_score = float('-inf')
        best_api = None

        print(f"Processing evaluations for {language}...\n")

        for api_name, lang_data in evaluations.items():
            if language not in lang_data:
                continue  # Skip if the language is not in the API's data

            image_metrics = lang_data[language]
            total_score = 0
            total_score_llm = 0
            total_lev_accuracy = 0
            total_word_accuracy = 0
            total_cer = 0
            total_lev_accuracy_llm = 0
            total_word_accuracy_llm = 0
            total_cer_llm = 0
            num_images = len(image_metrics)

            for image_name, metrics in image_metrics.items():
                total_score += (
                    alpha * metrics.get("Levenshtein Accuracy", 0) +
                    beta * metrics.get("Word Accuracy", 0) +
                    gamma * (1 - metrics.get("Character Error Rate", 0))
                )

                total_score_llm += (
                    alpha * metrics.get("Levenshtein Accuracy LLM", 0) +
                    beta * metrics.get("Word Accuracy LLM", 0) +
                    gamma * (1 - metrics.get("Character Error Rate LLM", 0))
                )

                total_lev_accuracy += metrics.get("Levenshtein Accuracy", 0)
                total_word_accuracy += metrics.get("Word Accuracy", 0)
                total_cer += metrics.get("Character Error Rate", 0)

                total_lev_accuracy_llm += metrics.get("Levenshtein Accuracy LLM", 0)
                total_word_accuracy_llm += metrics.get("Word Accuracy LLM", 0)
                total_cer_llm += metrics.get("Character Error Rate LLM", 0)

            avg_score = total_score / num_images if num_images > 0 else 0
            avg_score_llm = total_score_llm / num_images if num_images > 0 else 0

            avg_lev_accuracy = total_lev_accuracy / num_images if num_images > 0 else 0
            avg_word_accuracy = total_word_accuracy / num_images if num_images > 0 else 0
            avg_cer = total_cer / num_images if num_images > 0 else 0

            avg_lev_accuracy_llm = total_lev_accuracy_llm / num_images if num_images > 0 else 0
            avg_word_accuracy_llm = total_word_accuracy_llm / num_images if num_images > 0 else 0
            avg_cer_llm = total_cer_llm / num_images if num_images > 0 else 0

            print(f"{api_name} - {language}: Average Score: {avg_score:.2f}, with LLM: {avg_score_llm:.2f}")

            results.append({
                "API Name": api_name,
                "Levenshtein Accuracy": avg_lev_accuracy,
                "Levenshtein Accuracy with LLM": avg_lev_accuracy_llm,
                "Word Accuracy": avg_word_accuracy,
                "Word Accuracy with LLM": avg_word_accuracy_llm,
                "Character Error Rate": avg_cer,
                "Character Error Rate with LLM": avg_cer_llm,
                "Average Score": avg_score,
                "Average Score with LLM": avg_score_llm
            })

            if avg_score > best_score:
                best_score = avg_score
                best_api = api_name

        # Save results to Excel
        df = pd.DataFrame(results)
        file_name = f"{language}_ocr_evaluation_results.xlsx"
        df.to_excel(file_name, index=False)
        print(f"Results for {language} saved to {file_name}\n")

        # Store the best API for this language
        best_api_per_language[language] = {"Best API": best_api, "Best Score": best_score}

    return best_api_per_language

# %%
hard_languages
# Out:
# ['Arabic', 'Chinese', 'Korean', 'Japanese', 'Hindi']

# %%
Azure_Evaluation
# Out:
# {'Arabic': {'tr_img_00001': {'Levenshtein Accuracy': 26.630434782608692,
#    'Word Accuracy': 77.27272727272727,
#    'Character Error Rate': 82.53012048192771,
#    'Levenshtein Accuracy LLM': 28.260869565217394,
#    'Word Accuracy LLM': 77.27272727272727,
#    'Character Error Rate LLM': 80.72289156626506},
#   'tr_img_00002': {'Levenshtein Accuracy': 95.65217391304348,
#    'Word Accuracy': 80.0,
#    'Character Error Rate': 9.090909090909092,
#    'Levenshtein Accuracy LLM': 95.65217391304348,
#    'Word Accuracy LLM': 80.0,
#    'Character Error Rate LLM': 9.090909090909092},
#   'tr_img_00003': {'Levenshtein Accuracy': 51.162790697674424,
#    'Word Accuracy': 66.66666666666666,
#    'Character Error Rate': 48.837209302325576,
#    'Levenshtein Accuracy LLM': 46.51162790697675,
#    'Word Accuracy LLM': 66.66666666666666,
#    'Character Error Rate LLM': 53.48837209302325},
#   'tr_img_00004': {'Levenshtein Accuracy': 100.0,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 0.0,
#    'Levenshtein Accuracy LLM': 100.0,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 6.0606060606060606},
#   'tr_img_00005': {'Levenshtein Accuracy': 93.33333333333333,
#    'Word Accuracy': 50.0,
#    'Character Error Rate': 6.666666666666667,
#    'Levenshtein Accuracy LLM': 93.33333333333333,
#    'Word Accuracy LLM': 50.0,
#    'Character Error Rate LLM': 6.666666666666667},
#   'tr_img_00006': {'Levenshtein Accuracy': 100.0,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 0.0,
#    'Levenshtein Accuracy LLM': 47.36842105263158,
#    'Word Accuracy LLM': 25.0,
#    'Character Error Rate LLM': 52.63157894736842},
#   'tr_img_00007': {'Levenshtein Accuracy': 12.962962962962965,
#    'Word Accuracy': 60.0,
#    'Character Error Rate': 127.02702702702702,
#    'Levenshtein Accuracy LLM': 12.962962962962965,
#    'Word Accuracy LLM': 60.0,
#    'Character Error Rate LLM': 127.02702702702702},
#   'tr_img_00008': {'Levenshtein Accuracy': 96.66666666666667,
#    'Word Accuracy': 77.77777777777779,
#    'Character Error Rate': 3.4482758620689653,
#    'Levenshtein Accuracy LLM': 95.0,
#    'Word Accuracy LLM': 77.77777777777779,
#    'Character Error Rate LLM': 5.172413793103448},
#   'tr_img_00009': {'Levenshtein Accuracy': 100.0,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 0.0,
#    'Levenshtein Accuracy LLM': 100.0,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 0.0},
#   'tr_img_00010': {'Levenshtein Accuracy': 80.95238095238095,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 19.047619047619047,
#    'Levenshtein Accuracy LLM': 77.27272727272727,
#    'Word Accuracy LLM': 75.0,
#    'Character Error Rate LLM': 23.809523809523807},
#   'tr_img_00011': {'Levenshtein Accuracy': 39.39393939393939,
#    'Word Accuracy': 83.33333333333334,
#    'Character Error Rate': 61.53846153846154,
#    'Levenshtein Accuracy LLM': 36.92307692307693,
#    'Word Accuracy LLM': 75.0,
#    'Character Error Rate LLM': 63.07692307692307},
#   'tr_img_00012': {'Levenshtein Accuracy': 29.508196721311474,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 81.13207547169812,
#    'Levenshtein Accuracy LLM': 32.25806451612904,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 79.24528301886792},
#   'tr_img_00013': {'Levenshtein Accuracy': 100.0,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 0.0,
#    'Levenshtein Accuracy LLM': 80.0,
#    'Word Accuracy LLM': 66.66666666666666,
#    'Character Error Rate LLM': 21.052631578947366},
#   'tr_img_00014': {'Levenshtein Accuracy': 29.807692307692314,
#    'Word Accuracy': 91.66666666666666,
#    'Character Error Rate': 87.95180722891565,
#    'Levenshtein Accuracy LLM': 29.807692307692314,
#    'Word Accuracy LLM': 83.33333333333334,
#    'Character Error Rate LLM': 87.95180722891565},
#   'tr_img_00015': {'Levenshtein Accuracy': 51.28205128205128,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 51.35135135135135,
#    'Levenshtein Accuracy LLM': 51.35135135135135,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 48.64864864864865},
#   'tr_img_00016': {'Levenshtein Accuracy': 58.2089552238806,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 41.7910447761194,
#    'Levenshtein Accuracy LLM': 58.2089552238806,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 77.61194029850746},
#   'tr_img_00017': {'Levenshtein Accuracy': 56.81818181818181,
#    'Word Accuracy': 12.5,
#    'Character Error Rate': 46.34146341463415,
#    'Levenshtein Accuracy LLM': 65.85365853658536,
#    'Word Accuracy LLM': 37.5,
#    'Character Error Rate LLM': 34.146341463414636},
#   'tr_img_00018': {'Levenshtein Accuracy': 100.0,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 0.0,
#    'Levenshtein Accuracy LLM': 100.0,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 0.0},
#   'tr_img_00019': {'Levenshtein Accuracy': 57.24137931034483,
#    'Word Accuracy': 95.0,
#    'Character Error Rate': 48.9051094890511,
#    'Levenshtein Accuracy LLM': 57.55395683453237,
#    'Word Accuracy LLM': 95.0,
#    'Character Error Rate LLM': 45.25547445255474},
#   'tr_img_00020': {'Levenshtein Accuracy': 17.391304347826086,
#    'Word Accuracy': 80.0,
#    'Character Error Rate': 100.0,
#    'Levenshtein Accuracy LLM': 14.516129032258062,
#    'Word Accuracy LLM': 50.0,
#    'Character Error Rate LLM': 91.37931034482759},
#   'tr_img_00021': {'Levenshtein Accuracy': 61.53846153846154,
#    'Word Accuracy': 50.0,
#    'Character Error Rate': 62.5,
#    'Levenshtein Accuracy LLM': 50.0,
#    'Word Accuracy LLM': 50.0,
#    'Character Error Rate LLM': 87.5},
#   'tr_img_00022': {'Levenshtein Accuracy': 66.99029126213591,
#    'Word Accuracy': 81.81818181818183,
#    'Character Error Rate': 33.33333333333333,
#    'Levenshtein Accuracy LLM': 66.66666666666667,
#    'Word Accuracy LLM': 77.27272727272727,
#    'Character Error Rate LLM': 33.33333333333333},
#   'tr_img_00023': {'Levenshtein Accuracy': 75.0,
#    'Word Accuracy': 0.0,
#    'Character Error Rate': 25.0,
#    'Levenshtein Accuracy LLM': 50.0,
#    'Word Accuracy LLM': 0.0,
#    'Character Error Rate LLM': 50.0},
#   'tr_img_00025': {'Levenshtein Accuracy': 87.5,
#    'Word Accuracy': 50.0,
#    'Character Error Rate': 14.285714285714285,
#    'Levenshtein Accuracy LLM': 100.0,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 0.0},
#   'tr_img_00026': {'Levenshtein Accuracy': 77.58620689655173,
#    'Word Accuracy': 78.57142857142857,
#    'Character Error Rate': 22.413793103448278,
#    'Levenshtein Accuracy LLM': 76.72413793103449,
#    'Word Accuracy LLM': 71.42857142857143,
#    'Character Error Rate LLM': 23.275862068965516},
#   'tr_img_00027': {'Levenshtein Accuracy': 47.5,
#    'Word Accuracy': 57.14285714285714,
#    'Character Error Rate': 52.5,
#    'Levenshtein Accuracy LLM': 37.5,
#    'Word Accuracy LLM': 28.57142857142857,
#    'Character Error Rate LLM': 62.5},
#   'tr_img_00028': {'Levenshtein Accuracy': 50.0,
#    'Word Accuracy': 72.72727272727273,
#    'Character Error Rate': 50.0,
#    'Levenshtein Accuracy LLM': 48.484848484848484,
#    'Word Accuracy LLM': 45.45454545454545,
#    'Character Error Rate LLM': 51.515151515151516},
#   'tr_img_00029': {'Levenshtein Accuracy': 75.60975609756098,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 24.390243902439025,
#    'Levenshtein Accuracy LLM': 75.60975609756098,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 24.390243902439025},
#   'tr_img_00031': {'Levenshtein Accuracy': 48.14814814814815,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 51.85185185185185,
#    'Levenshtein Accuracy LLM': 48.14814814814815,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 59.25925925925925},
#   'tr_img_00032': {'Levenshtein Accuracy': 100.0,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 0.0,
#    'Levenshtein Accuracy LLM': 100.0,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 0.0},
#   'tr_img_00033': {'Levenshtein Accuracy': 39.53488372093024,
#    'Word Accuracy': 62.5,
#    'Character Error Rate': 63.41463414634146,
#    'Levenshtein Accuracy LLM': 36.58536585365854,
#    'Word Accuracy LLM': 62.5,
#    'Character Error Rate LLM': 63.41463414634146},
#   'tr_img_00034': {'Levenshtein Accuracy': 52.94117647058824,
#    'Word Accuracy': 73.33333333333333,
#    'Character Error Rate': 53.333333333333336,
#    'Levenshtein Accuracy LLM': 52.475247524752476,
#    'Word Accuracy LLM': 66.66666666666666,
#    'Character Error Rate LLM': 53.333333333333336},
#   'tr_img_00035': {'Levenshtein Accuracy': 100.0,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 0.0,
#    'Levenshtein Accuracy LLM': 100.0,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 0.0},
#   'tr_img_00036': {'Levenshtein Accuracy': 22.499999999999996,
#    'Word Accuracy': 83.33333333333334,
#    'Character Error Rate': 77.5,
#    'Levenshtein Accuracy LLM': 21.95121951219512,
#    'Word Accuracy LLM': 50.0,
#    'Character Error Rate LLM': 80.0},
#   'tr_img_00037': {'Levenshtein Accuracy': 100.0,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 0.0,
#    'Levenshtein Accuracy LLM': 100.0,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 0.0},
#   'tr_img_00038': {'Levenshtein Accuracy': 43.99999999999999,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 127.27272727272727,
#    'Levenshtein Accuracy LLM': 40.789473684210535,
#    'Word Accuracy LLM': 66.66666666666666,
#    'Character Error Rate LLM': 136.36363636363635},
#   'tr_img_00039': {'Levenshtein Accuracy': 68.75,
#    'Word Accuracy': 0.0,
#    'Character Error Rate': 31.25,
#    'Levenshtein Accuracy LLM': 62.5,
#    'Word Accuracy LLM': 0.0,
#    'Character Error Rate LLM': 37.5},
#   'tr_img_00040': {'Levenshtein Accuracy': 54.92957746478873,
#    'Word Accuracy': 83.33333333333334,
#    'Character Error Rate': 51.61290322580645,
#    'Levenshtein Accuracy LLM': 53.2258064516129,
#    'Word Accuracy LLM': 75.0,
#    'Character Error Rate LLM': 46.774193548387096},
#   'tr_img_00041': {'Levenshtein Accuracy': 96.66666666666667,
#    'Word Accuracy': 75.0,
#    'Character Error Rate': 3.3333333333333335,
#    'Levenshtein Accuracy LLM': 96.66666666666667,
#    'Word Accuracy LLM': 75.0,
#    'Character Error Rate LLM': 3.3333333333333335},
#   'tr_img_00042': {'Levenshtein Accuracy': 6.666666666666665,
#    'Word Accuracy': 85.71428571428571,
#    'Character Error Rate': 93.33333333333333,
#    'Levenshtein Accuracy LLM': 6.666666666666665,
#    'Word Accuracy LLM': 85.71428571428571,
#    'Character Error Rate LLM': 93.33333333333333},
#   'tr_img_00043': {'Levenshtein Accuracy': 61.53846153846154,
#    'Word Accuracy': 50.0,
#    'Character Error Rate': 38.46153846153847,
#    'Levenshtein Accuracy LLM': 53.84615384615385,
#    'Word Accuracy LLM': 25.0,
#    'Character Error Rate LLM': 46.15384615384615},
#   'tr_img_00044': {'Levenshtein Accuracy': 83.78378378378379,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 19.35483870967742,
#    'Levenshtein Accuracy LLM': 61.29032258064516,
#    'Word Accuracy LLM': 66.66666666666666,
#    'Character Error Rate LLM': 38.70967741935484},
#   'tr_img_00045': {'Levenshtein Accuracy': 38.095238095238095,
#    'Word Accuracy': 0.0,
#    'Character Error Rate': 61.904761904761905,
#    'Levenshtein Accuracy LLM': 14.28571428571429,
#    'Word Accuracy LLM': 0.0,
#    'Character Error Rate LLM': 85.71428571428571},
#   'tr_img_00046': {'Levenshtein Accuracy': 91.30434782608697,
#    'Word Accuracy': 75.0,
#    'Character Error Rate': 8.695652173913043,
#    'Levenshtein Accuracy LLM': 86.95652173913044,
#    'Word Accuracy LLM': 50.0,
#    'Character Error Rate LLM': 13.043478260869565},
#   'tr_img_00047': {'Levenshtein Accuracy': 62.31884057971014,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 47.27272727272727,
#    'Levenshtein Accuracy LLM': 63.23529411764706,
#    'Word Accuracy LLM': 90.0,
#    'Character Error Rate LLM': 45.45454545454545},
#   'tr_img_00048': {'Levenshtein Accuracy': 43.05555555555556,
#    'Word Accuracy': 55.55555555555556,
#    'Character Error Rate': 59.42028985507246,
#    'Levenshtein Accuracy LLM': 40.54054054054054,
#    'Word Accuracy LLM': 33.33333333333333,
#    'Character Error Rate LLM': 95.65217391304348},
#   'tr_img_00049': {'Levenshtein Accuracy': 73.91304347826086,
#    'Word Accuracy': 60.0,
#    'Character Error Rate': 26.08695652173913,
#    'Levenshtein Accuracy LLM': 56.52173913043479,
#    'Word Accuracy LLM': 40.0,
#    'Character Error Rate LLM': 43.47826086956522},
#   'tr_img_00050': {'Levenshtein Accuracy': 75.0,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 29.411764705882355,
#    'Levenshtein Accuracy LLM': 64.86486486486487,
#    'Word Accuracy LLM': 83.33333333333334,
#    'Character Error Rate LLM': 38.23529411764706},
#   'tr_img_00051': {'Levenshtein Accuracy': 100.0,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 0.0,
#    'Levenshtein Accuracy LLM': 100.0,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 0.0},
#   'tr_img_00052': {'Levenshtein Accuracy': 21.604938271604933,
#    'Word Accuracy': 72.22222222222221,
#    'Character Error Rate': 112.82051282051282,
#    'Levenshtein Accuracy LLM': 21.250000000000004,
#    'Word Accuracy LLM': 72.22222222222221,
#    'Character Error Rate LLM': 111.11111111111111}},
#  'English': {'tr_img_01001': {'Levenshtein Accuracy': 100.0,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 0.0,
#    'Levenshtein Accuracy LLM': 100.0,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 0.0},
#   'tr_img_01002': {'Levenshtein Accuracy': 96.07843137254902,
#    'Word Accuracy': 75.0,
#    'Character Error Rate': 3.9215686274509802,
#    'Levenshtein Accuracy LLM': 100.0,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 5.88235294117647},
#   'tr_img_01003': {'Levenshtein Accuracy': 38.095238095238095,
#    'Word Accuracy': 60.0,
#    'Character Error Rate': 69.84126984126983,
#    'Levenshtein Accuracy LLM': 36.50793650793651,
#    'Word Accuracy LLM': 50.0,
#    'Character Error Rate LLM': 71.42857142857143},
#   'tr_img_01004': {'Levenshtein Accuracy': 100.0,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 0.0,
#    'Levenshtein Accuracy LLM': 100.0,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 0.0},
#   'tr_img_01005': {'Levenshtein Accuracy': 79.3103448275862,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 26.08695652173913,
#    'Levenshtein Accuracy LLM': 76.66666666666666,
#    'Word Accuracy LLM': 75.0,
#    'Character Error Rate LLM': 65.21739130434783},
#   'tr_img_01006': {'Levenshtein Accuracy': 54.83870967741935,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 45.16129032258064,
#    'Levenshtein Accuracy LLM': 54.83870967741935,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 74.19354838709677},
#   'tr_img_01007': {'Levenshtein Accuracy': 44.91525423728814,
#    'Word Accuracy': 70.58823529411765,
#    'Character Error Rate': 60.16949152542372,
#    'Levenshtein Accuracy LLM': 48.30508474576271,
#    'Word Accuracy LLM': 70.58823529411765,
#    'Character Error Rate LLM': 57.6271186440678},
#   'tr_img_01008': {'Levenshtein Accuracy': 89.47368421052632,
#    'Word Accuracy': 75.0,
#    'Character Error Rate': 10.526315789473683,
#    'Levenshtein Accuracy LLM': 89.47368421052632,
#    'Word Accuracy LLM': 75.0,
#    'Character Error Rate LLM': 10.526315789473683},
#   'tr_img_01009': {'Levenshtein Accuracy': 85.71428571428572,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 16.666666666666664,
#    'Levenshtein Accuracy LLM': 85.71428571428572,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 16.666666666666664},
#   'tr_img_01011': {'Levenshtein Accuracy': 100.0,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 0.0,
#    'Levenshtein Accuracy LLM': 100.0,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 0.0},
#   'tr_img_01012': {'Levenshtein Accuracy': 56.33802816901409,
#    'Word Accuracy': 89.47368421052632,
#    'Character Error Rate': 45.32374100719424,
#    'Levenshtein Accuracy LLM': 50.35971223021583,
#    'Word Accuracy LLM': 47.368421052631575,
#    'Character Error Rate LLM': 50.35971223021583},
#   'tr_img_01013': {'Levenshtein Accuracy': 84.21052631578947,
#    'Word Accuracy': 66.66666666666666,
#    'Character Error Rate': 25.0,
#    'Levenshtein Accuracy LLM': 84.21052631578947,
#    'Word Accuracy LLM': 66.66666666666666,
#    'Character Error Rate LLM': 25.0},
#   'tr_img_01017': {'Levenshtein Accuracy': 100.0,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 0.0,
#    'Levenshtein Accuracy LLM': 100.0,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 0.0},
#   'tr_img_01018': {'Levenshtein Accuracy': 44.827586206896555,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 68.08510638297872,
#    'Levenshtein Accuracy LLM': 42.85714285714286,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 70.2127659574468},
#   'tr_img_01019': {'Levenshtein Accuracy': 100.0,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 0.0,
#    'Levenshtein Accuracy LLM': 100.0,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 0.0},
#   'tr_img_01021': {'Levenshtein Accuracy': 50.0,
#    'Word Accuracy': 66.66666666666666,
#    'Character Error Rate': 63.1578947368421,
#    'Levenshtein Accuracy LLM': 50.0,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 63.1578947368421},
#   'tr_img_01023': {'Levenshtein Accuracy': 96.55172413793103,
#    'Word Accuracy': 80.0,
#    'Character Error Rate': 3.571428571428571,
#    'Levenshtein Accuracy LLM': 96.55172413793103,
#    'Word Accuracy LLM': 80.0,
#    'Character Error Rate LLM': 25.0},
#   'tr_img_01024': {'Levenshtein Accuracy': 100.0,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 0.0,
#    'Levenshtein Accuracy LLM': 90.0,
#    'Word Accuracy LLM': 0.0,
#    'Character Error Rate LLM': 11.11111111111111},
#   'tr_img_01025': {'Levenshtein Accuracy': 100.0,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 0.0,
#    'Levenshtein Accuracy LLM': 100.0,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 0.0},
#   'tr_img_01026': {'Levenshtein Accuracy': 100.0,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 0.0,
#    'Levenshtein Accuracy LLM': 100.0,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 80.0},
#   'tr_img_01027': {'Levenshtein Accuracy': 53.623188405797094,
#    'Word Accuracy': 75.0,
#    'Character Error Rate': 64.0,
#    'Levenshtein Accuracy LLM': 55.73770491803278,
#    'Word Accuracy LLM': 75.0,
#    'Character Error Rate LLM': 54.0},
#   'tr_img_01028': {'Levenshtein Accuracy': 9.523809523809524,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 95.23809523809523,
#    'Levenshtein Accuracy LLM': 9.523809523809524,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 95.23809523809523},
#   'tr_img_01029': {'Levenshtein Accuracy': 100.0,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 0.0,
#    'Levenshtein Accuracy LLM': 100.0,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 0.0},
#   'tr_img_01030': {'Levenshtein Accuracy': 61.53846153846154,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 62.5,
#    'Levenshtein Accuracy LLM': 61.53846153846154,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 62.5},
#   'tr_img_01031': {'Levenshtein Accuracy': 86.20689655172413,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 16.0,
#    'Levenshtein Accuracy LLM': 86.20689655172413,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 96.0},
#   'tr_img_01032': {'Levenshtein Accuracy': 100.0,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 0.0,
#    'Levenshtein Accuracy LLM': 100.0,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 0.0},
#   'tr_img_01034': {'Levenshtein Accuracy': 100.0,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 0.0,
#    'Levenshtein Accuracy LLM': 100.0,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 0.0},
#   'tr_img_01035': {'Levenshtein Accuracy': 100.0,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 0.0,
#    'Levenshtein Accuracy LLM': 100.0,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 0.0},
#   'tr_img_01036': {'Levenshtein Accuracy': 100.0,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 0.0,
#    'Levenshtein Accuracy LLM': 100.0,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 0.0},
#   'tr_img_01037': {'Levenshtein Accuracy': 58.22784810126582,
#    'Word Accuracy': 50.0,
#    'Character Error Rate': 41.77215189873418,
#    'Levenshtein Accuracy LLM': 60.75949367088608,
#    'Word Accuracy LLM': 50.0,
#    'Character Error Rate LLM': 39.24050632911392},
#   'tr_img_01038': {'Levenshtein Accuracy': 100.0,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 0.0,
#    'Levenshtein Accuracy LLM': 100.0,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 52.38095238095239},
#   'tr_img_01039': {'Levenshtein Accuracy': 100.0,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 0.0,
#    'Levenshtein Accuracy LLM': 100.0,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 0.0},
#   'tr_img_01040': {'Levenshtein Accuracy': 100.0,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 0.0,
#    'Levenshtein Accuracy LLM': 100.0,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 0.0},
#   'tr_img_01041': {'Levenshtein Accuracy': 88.88888888888889,
#    'Word Accuracy': 50.0,
#    'Character Error Rate': 11.11111111111111,
#    'Levenshtein Accuracy LLM': 88.88888888888889,
#    'Word Accuracy LLM': 50.0,
#    'Character Error Rate LLM': 66.66666666666666},
#   'tr_img_01042': {'Levenshtein Accuracy': 62.96296296296296,
#    'Word Accuracy': 66.66666666666666,
#    'Character Error Rate': 55.55555555555556,
#    'Levenshtein Accuracy LLM': 60.71428571428572,
#    'Word Accuracy LLM': 66.66666666666666,
#    'Character Error Rate LLM': 61.111111111111114},
#   'tr_img_01044': {'Levenshtein Accuracy': 34.523809523809526,
#    'Word Accuracy': 91.66666666666666,
#    'Character Error Rate': 76.62337662337663,
#    'Levenshtein Accuracy LLM': 36.47058823529412,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 75.32467532467533},
#   'tr_img_01045': {'Levenshtein Accuracy': 52.542372881355924,
#    'Word Accuracy': 88.88888888888889,
#    'Character Error Rate': 59.57446808510638,
#    'Levenshtein Accuracy LLM': 54.385964912280706,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 63.829787234042556},
#   'tr_img_01046': {'Levenshtein Accuracy': 92.0,
#    'Word Accuracy': 83.33333333333334,
#    'Character Error Rate': 8.0,
#    'Levenshtein Accuracy LLM': 92.0,
#    'Word Accuracy LLM': 83.33333333333334,
#    'Character Error Rate LLM': 8.0},
#   'tr_img_01047': {'Levenshtein Accuracy': 98.11320754716981,
#    'Word Accuracy': 85.71428571428571,
#    'Character Error Rate': 1.9230769230769231,
#    'Levenshtein Accuracy LLM': 92.85714285714286,
#    'Word Accuracy LLM': 42.857142857142854,
#    'Character Error Rate LLM': 9.615384615384617},
#   'tr_img_01048': {'Levenshtein Accuracy': 30.87248322147651,
#    'Word Accuracy': 92.85714285714286,
#    'Character Error Rate': 94.54545454545455,
#    'Levenshtein Accuracy LLM': 29.605263157894733,
#    'Word Accuracy LLM': 85.71428571428571,
#    'Character Error Rate LLM': 97.27272727272728},
#   'tr_img_01049': {'Levenshtein Accuracy': 40.0,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 150.0,
#    'Levenshtein Accuracy LLM': 40.0,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 150.0},
#   'tr_img_01050': {'Levenshtein Accuracy': 23.529411764705888,
#    'Word Accuracy': 60.0,
#    'Character Error Rate': 150.0,
#    'Levenshtein Accuracy LLM': 24.0,
#    'Word Accuracy LLM': 60.0,
#    'Character Error Rate LLM': 146.15384615384613},
#   'tr_img_01051': {'Levenshtein Accuracy': 100.0,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 0.0,
#    'Levenshtein Accuracy LLM': 100.0,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 0.0},
#   'tr_img_01052': {'Levenshtein Accuracy': 100.0,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 0.0,
#    'Levenshtein Accuracy LLM': 100.0,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 0.0},
#   'tr_img_01054': {'Levenshtein Accuracy': 100.0,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 0.0,
#    'Levenshtein Accuracy LLM': 100.0,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 0.0},
#   'tr_img_01055': {'Levenshtein Accuracy': 26.086956521739136,
#    'Word Accuracy': 71.42857142857143,
#    'Character Error Rate': 73.91304347826086,
#    'Levenshtein Accuracy LLM': 26.086956521739136,
#    'Word Accuracy LLM': 71.42857142857143,
#    'Character Error Rate LLM': 73.91304347826086},
#   'tr_img_01059': {'Levenshtein Accuracy': 100.0,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 0.0,
#    'Levenshtein Accuracy LLM': 100.0,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 0.0},
#   'tr_img_01060': {'Levenshtein Accuracy': 44.44444444444444,
#    'Word Accuracy': 66.66666666666666,
#    'Character Error Rate': 71.42857142857143,
#    'Levenshtein Accuracy LLM': 44.44444444444444,
#    'Word Accuracy LLM': 66.66666666666666,
#    'Character Error Rate LLM': 92.85714285714286},
#   'tr_img_01061': {'Levenshtein Accuracy': 62.16216216216216,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 37.83783783783784,
#    'Levenshtein Accuracy LLM': 62.16216216216216,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 37.83783783783784},
#   'tr_img_01062': {'Levenshtein Accuracy': 77.77777777777779,
#    'Word Accuracy': 66.66666666666666,
#    'Character Error Rate': 22.22222222222222,
#    'Levenshtein Accuracy LLM': 77.77777777777779,
#    'Word Accuracy LLM': 66.66666666666666,
#    'Character Error Rate LLM': 83.33333333333334}},
#  'French': {'tr_img_02001': {'Levenshtein Accuracy': 94.73684210526316,
#    'Word Accuracy': 66.66666666666666,
#    'Character Error Rate': 5.263157894736842,
#    'Levenshtein Accuracy LLM': 94.73684210526316,
#    'Word Accuracy LLM': 66.66666666666666,
#    'Character Error Rate LLM': 5.263157894736842},
#   'tr_img_02002': {'Levenshtein Accuracy': 47.916666666666664,
#    'Word Accuracy': 23.076923076923077,
#    'Character Error Rate': 64.58333333333334,
#    'Levenshtein Accuracy LLM': 47.916666666666664,
#    'Word Accuracy LLM': 30.76923076923077,
#    'Character Error Rate LLM': 64.58333333333334},
#   'tr_img_02003': {'Levenshtein Accuracy': 100.0,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 0.0,
#    'Levenshtein Accuracy LLM': 100.0,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 0.0},
#   'tr_img_02004': {'Levenshtein Accuracy': 50.0,
#    'Word Accuracy': 33.33333333333333,
#    'Character Error Rate': 50.0,
#    'Levenshtein Accuracy LLM': 25.0,
#    'Word Accuracy LLM': 0.0,
#    'Character Error Rate LLM': 75.0},
#   'tr_img_02005': {'Levenshtein Accuracy': 47.11538461538461,
#    'Word Accuracy': 78.57142857142857,
#    'Character Error Rate': 56.86274509803921,
#    'Levenshtein Accuracy LLM': 47.11538461538461,
#    'Word Accuracy LLM': 64.28571428571429,
#    'Character Error Rate LLM': 57.84313725490197},
#   'tr_img_02006': {'Levenshtein Accuracy': 100.0,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 0.0,
#    'Levenshtein Accuracy LLM': 100.0,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 0.0},
#   'tr_img_02007': {'Levenshtein Accuracy': 93.33333333333333,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 6.666666666666667,
#    'Levenshtein Accuracy LLM': 93.33333333333333,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 6.666666666666667},
#   'tr_img_02008': {'Levenshtein Accuracy': 100.0,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 0.0,
#    'Levenshtein Accuracy LLM': 100.0,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 5.88235294117647},
#   'tr_img_02011': {'Levenshtein Accuracy': 100.0,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 0.0,
#    'Levenshtein Accuracy LLM': 100.0,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 26.08695652173913},
#   'tr_img_02012': {'Levenshtein Accuracy': 78.125,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 28.000000000000004,
#    'Levenshtein Accuracy LLM': 78.125,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 36.0},
#   'tr_img_02013': {'Levenshtein Accuracy': 100.0,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 0.0,
#    'Levenshtein Accuracy LLM': 100.0,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 0.0},
#   'tr_img_02015': {'Levenshtein Accuracy': 88.23529411764706,
#    'Word Accuracy': 50.0,
#    'Character Error Rate': 11.76470588235294,
#    'Levenshtein Accuracy LLM': 88.23529411764706,
#    'Word Accuracy LLM': 50.0,
#    'Character Error Rate LLM': 11.76470588235294},
#   'tr_img_02016': {'Levenshtein Accuracy': 100.0,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 0.0,
#    'Levenshtein Accuracy LLM': 100.0,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 0.0},
#   'tr_img_02017': {'Levenshtein Accuracy': 100.0,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 0.0,
#    'Levenshtein Accuracy LLM': 97.05882352941177,
#    'Word Accuracy LLM': 80.0,
#    'Character Error Rate LLM': 2.941176470588235},
#   'tr_img_02018': {'Levenshtein Accuracy': 97.77777777777777,
#    'Word Accuracy': 85.71428571428571,
#    'Character Error Rate': 2.272727272727273,
#    'Levenshtein Accuracy LLM': 100.0,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 0.0},
#   'tr_img_02019': {'Levenshtein Accuracy': 100.0,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 0.0,
#    'Levenshtein Accuracy LLM': 100.0,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 0.0},
#   'tr_img_02020': {'Levenshtein Accuracy': 42.22222222222223,
#    'Word Accuracy': 66.66666666666666,
#    'Character Error Rate': 57.77777777777777,
#    'Levenshtein Accuracy LLM': 42.22222222222223,
#    'Word Accuracy LLM': 66.66666666666666,
#    'Character Error Rate LLM': 57.77777777777777},
#   'tr_img_02021': {'Levenshtein Accuracy': 100.0,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 0.0,
#    'Levenshtein Accuracy LLM': 100.0,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 0.0},
#   'tr_img_02022': {'Levenshtein Accuracy': 26.190476190476186,
#    'Word Accuracy': 0.0,
#    'Character Error Rate': 73.80952380952381,
#    'Levenshtein Accuracy LLM': 35.71428571428571,
#    'Word Accuracy LLM': 14.285714285714285,
#    'Character Error Rate LLM': 64.28571428571429},
#   'tr_img_02023': {'Levenshtein Accuracy': 100.0,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 0.0,
#    'Levenshtein Accuracy LLM': 95.0,
#    'Word Accuracy LLM': 66.66666666666666,
#    'Character Error Rate LLM': 65.0},
#   'tr_img_02024': {'Levenshtein Accuracy': 89.24731182795699,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 12.048192771084338,
#    'Levenshtein Accuracy LLM': 88.29787234042553,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 13.253012048192772},
#   'tr_img_02025': {'Levenshtein Accuracy': 100.0,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 0.0,
#    'Levenshtein Accuracy LLM': 100.0,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 18.421052631578945},
#   'tr_img_02028': {'Levenshtein Accuracy': 28.57142857142857,
#    'Word Accuracy': 83.33333333333334,
#    'Character Error Rate': 90.9090909090909,
#    'Levenshtein Accuracy LLM': 30.434782608695656,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 87.27272727272727},
#   'tr_img_02029': {'Levenshtein Accuracy': 92.0,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 8.695652173913043,
#    'Levenshtein Accuracy LLM': 100.0,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 0.0},
#   'tr_img_02030': {'Levenshtein Accuracy': 38.46153846153846,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 61.53846153846154,
#    'Levenshtein Accuracy LLM': 35.71428571428571,
#    'Word Accuracy LLM': 75.0,
#    'Character Error Rate LLM': 69.23076923076923},
#   'tr_img_02031': {'Levenshtein Accuracy': 55.10204081632652,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 44.89795918367347,
#    'Levenshtein Accuracy LLM': 55.10204081632652,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 44.89795918367347},
#   'tr_img_02032': {'Levenshtein Accuracy': 50.0,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 58.69565217391305,
#    'Levenshtein Accuracy LLM': 50.0,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 60.86956521739131},
#   'tr_img_02033': {'Levenshtein Accuracy': 50.66666666666666,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 58.2089552238806,
#    'Levenshtein Accuracy LLM': 43.28358208955224,
#    'Word Accuracy LLM': 73.33333333333333,
#    'Character Error Rate LLM': 59.70149253731343},
#   'tr_img_02034': {'Levenshtein Accuracy': 100.0,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 0.0,
#    'Levenshtein Accuracy LLM': 100.0,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 0.0},
#   'tr_img_02035': {'Levenshtein Accuracy': 100.0,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 0.0,
#    'Levenshtein Accuracy LLM': 100.0,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 0.0},
#   'tr_img_02036': {'Levenshtein Accuracy': 65.51724137931035,
#    'Word Accuracy': 75.0,
#    'Character Error Rate': 40.0,
#    'Levenshtein Accuracy LLM': 65.51724137931035,
#    'Word Accuracy LLM': 75.0,
#    'Character Error Rate LLM': 52.0},
#   'tr_img_02037': {'Levenshtein Accuracy': 93.75,
#    'Word Accuracy': 66.66666666666666,
#    'Character Error Rate': 6.25,
#    'Levenshtein Accuracy LLM': 68.75,
#    'Word Accuracy LLM': 0.0,
#    'Character Error Rate LLM': 31.25},
#   'tr_img_02038': {'Levenshtein Accuracy': 33.333333333333336,
#    'Word Accuracy': 0.0,
#    'Character Error Rate': 66.66666666666666,
#    'Levenshtein Accuracy LLM': 22.22222222222222,
#    'Word Accuracy LLM': 0.0,
#    'Character Error Rate LLM': 77.77777777777779},
#   'tr_img_02039': {'Levenshtein Accuracy': 83.07692307692307,
#    'Word Accuracy': 80.0,
#    'Character Error Rate': 16.923076923076923,
#    'Levenshtein Accuracy LLM': 83.07692307692307,
#    'Word Accuracy LLM': 80.0,
#    'Character Error Rate LLM': 18.461538461538463},
#   'tr_img_02040': {'Levenshtein Accuracy': 100.0,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 0.0,
#    'Levenshtein Accuracy LLM': 100.0,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 0.0},
#   'tr_img_02041': {'Levenshtein Accuracy': 36.36363636363637,
#    'Word Accuracy': 0.0,
#    'Character Error Rate': 87.5,
#    'Levenshtein Accuracy LLM': 36.36363636363637,
#    'Word Accuracy LLM': 0.0,
#    'Character Error Rate LLM': 87.5},
#   'tr_img_02042': {'Levenshtein Accuracy': 100.0,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 0.0,
#    'Levenshtein Accuracy LLM': 95.23809523809523,
#    'Word Accuracy LLM': 75.0,
#    'Character Error Rate LLM': 4.761904761904762},
#   'tr_img_02043': {'Levenshtein Accuracy': 100.0,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 0.0,
#    'Levenshtein Accuracy LLM': 100.0,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 0.0},
#   'tr_img_02044': {'Levenshtein Accuracy': 85.0,
#    'Word Accuracy': 33.33333333333333,
#    'Character Error Rate': 16.666666666666664,
#    'Levenshtein Accuracy LLM': 89.47368421052632,
#    'Word Accuracy LLM': 66.66666666666666,
#    'Character Error Rate LLM': 11.11111111111111},
#   'tr_img_02045': {'Levenshtein Accuracy': 47.82608695652174,
#    'Word Accuracy': 75.0,
#    'Character Error Rate': 63.1578947368421,
#    'Levenshtein Accuracy LLM': 47.82608695652174,
#    'Word Accuracy LLM': 75.0,
#    'Character Error Rate LLM': 63.1578947368421},
#   'tr_img_02046': {'Levenshtein Accuracy': 100.0,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 5.0,
#    'Levenshtein Accuracy LLM': 100.0,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 5.0},
#   'tr_img_02047': {'Levenshtein Accuracy': 100.0,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 0.0,
#    'Levenshtein Accuracy LLM': 100.0,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 0.0},
#   'tr_img_02048': {'Levenshtein Accuracy': 100.0,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 0.0,
#    'Levenshtein Accuracy LLM': 100.0,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 0.0},
#   'tr_img_02049': {'Levenshtein Accuracy': 100.0,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 0.0,
#    'Levenshtein Accuracy LLM': 88.57142857142857,
#    'Word Accuracy LLM': 83.33333333333334,
#    'Character Error Rate LLM': 11.428571428571429},
#   'tr_img_02050': {'Levenshtein Accuracy': 80.0,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 25.0,
#    'Levenshtein Accuracy LLM': 80.0,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 25.0},
#   'tr_img_02051': {'Levenshtein Accuracy': 100.0,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 0.0,
#    'Levenshtein Accuracy LLM': 100.0,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 0.0},
#   'tr_img_02052': {'Levenshtein Accuracy': 56.97674418604651,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 49.333333333333336,
#    'Levenshtein Accuracy LLM': 43.01075268817204,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 70.66666666666667},
#   'tr_img_02053': {'Levenshtein Accuracy': 100.0,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 0.0,
#    'Levenshtein Accuracy LLM': 100.0,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 0.0},
#   'tr_img_02055': {'Levenshtein Accuracy': 96.66666666666667,
#    'Word Accuracy': 80.0,
#    'Character Error Rate': 3.3333333333333335,
#    'Levenshtein Accuracy LLM': 100.0,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 0.0},
#   'tr_img_02057': {'Levenshtein Accuracy': 100.0,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 0.0,
#    'Levenshtein Accuracy LLM': 100.0,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 0.0}},
#  'Chinese': {'tr_img_03001': {'Levenshtein Accuracy': 19.999999999999996,
#    'Word Accuracy': 60.0,
#    'Character Error Rate': 93.93939393939394,
#    'Levenshtein Accuracy LLM': 19.999999999999996,
#    'Word Accuracy LLM': 60.0,
#    'Character Error Rate LLM': 93.93939393939394},
#   'tr_img_03002': {'Levenshtein Accuracy': 31.57894736842105,
#    'Word Accuracy': 81.81818181818183,
#    'Character Error Rate': 68.42105263157895,
#    'Levenshtein Accuracy LLM': 23.684210526315784,
#    'Word Accuracy LLM': 0.0,
#    'Character Error Rate LLM': 76.31578947368422},
#   'tr_img_03003': {'Levenshtein Accuracy': 44.99999999999999,
#    'Word Accuracy': 0.0,
#    'Character Error Rate': 86.8421052631579,
#    'Levenshtein Accuracy LLM': 35.18518518518518,
#    'Word Accuracy LLM': 0.0,
#    'Character Error Rate LLM': 92.10526315789474},
#   'tr_img_03004': {'Levenshtein Accuracy': 47.82608695652174,
#    'Word Accuracy': 42.857142857142854,
#    'Character Error Rate': 73.17073170731707,
#    'Levenshtein Accuracy LLM': 43.220338983050844,
#    'Word Accuracy LLM': 0.0,
#    'Character Error Rate LLM': 81.70731707317073},
#   'tr_img_03007': {'Levenshtein Accuracy': 72.97297297297297,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 27.027027027027028,
#    'Levenshtein Accuracy LLM': 72.97297297297297,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 27.027027027027028},
#   'tr_img_03011': {'Levenshtein Accuracy': 100.0,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 0.0,
#    'Levenshtein Accuracy LLM': 100.0,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 0.0},
#   'tr_img_03012': {'Levenshtein Accuracy': 100.0,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 0.0,
#    'Levenshtein Accuracy LLM': 100.0,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 0.0},
#   'tr_img_03013': {'Levenshtein Accuracy': 73.17073170731707,
#    'Word Accuracy': 62.5,
#    'Character Error Rate': 26.82926829268293,
#    'Levenshtein Accuracy LLM': 73.17073170731707,
#    'Word Accuracy LLM': 62.5,
#    'Character Error Rate LLM': 26.82926829268293},
#   'tr_img_03014': {'Levenshtein Accuracy': 18.181818181818176,
#    'Word Accuracy': 0.0,
#    'Character Error Rate': 81.81818181818183,
#    'Levenshtein Accuracy LLM': 27.27272727272727,
#    'Word Accuracy LLM': 0.0,
#    'Character Error Rate LLM': 72.72727272727273},
#   'tr_img_03017': {'Levenshtein Accuracy': 97.72727272727273,
#    'Word Accuracy': 80.0,
#    'Character Error Rate': 2.272727272727273,
#    'Levenshtein Accuracy LLM': 90.9090909090909,
#    'Word Accuracy LLM': 60.0,
#    'Character Error Rate LLM': 9.090909090909092},
#   'tr_img_03018': {'Levenshtein Accuracy': 24.52830188679245,
#    'Word Accuracy': 72.72727272727273,
#    'Character Error Rate': 83.33333333333334,
#    'Levenshtein Accuracy LLM': 24.52830188679245,
#    'Word Accuracy LLM': 81.81818181818183,
#    'Character Error Rate LLM': 83.33333333333334},
#   'tr_img_03022': {'Levenshtein Accuracy': 97.05882352941177,
#    'Word Accuracy': 60.0,
#    'Character Error Rate': 2.941176470588235,
#    'Levenshtein Accuracy LLM': 94.11764705882352,
#    'Word Accuracy LLM': 40.0,
#    'Character Error Rate LLM': 5.88235294117647},
#   'tr_img_03024': {'Levenshtein Accuracy': 100.0,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 0.0,
#    'Levenshtein Accuracy LLM': 100.0,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 0.0},
#   'tr_img_03026': {'Levenshtein Accuracy': 100.0,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 0.0,
#    'Levenshtein Accuracy LLM': 100.0,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 0.0},
#   'tr_img_03027': {'Levenshtein Accuracy': 100.0,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 0.0,
#    'Levenshtein Accuracy LLM': 100.0,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 0.0},
#   'tr_img_03028': {'Levenshtein Accuracy': 72.72727272727273,
#    'Word Accuracy': 0.0,
#    'Character Error Rate': 33.33333333333333,
#    'Levenshtein Accuracy LLM': 66.66666666666667,
#    'Word Accuracy LLM': 0.0,
#    'Character Error Rate LLM': 33.33333333333333},
#   'tr_img_03029': {'Levenshtein Accuracy': 54.16666666666667,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 45.83333333333333,
#    'Levenshtein Accuracy LLM': 72.91666666666667,
#    'Word Accuracy LLM': 80.0,
#    'Character Error Rate LLM': 27.083333333333332},
#   'tr_img_03031': {'Levenshtein Accuracy': 69.23076923076923,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 30.76923076923077,
#    'Levenshtein Accuracy LLM': 69.23076923076923,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 30.76923076923077},
#   'tr_img_03033': {'Levenshtein Accuracy': 61.48148148148148,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 38.51851851851852,
#    'Levenshtein Accuracy LLM': 61.48148148148148,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 38.51851851851852},
#   'tr_img_03034': {'Levenshtein Accuracy': 100.0,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 0.0,
#    'Levenshtein Accuracy LLM': 91.66666666666666,
#    'Word Accuracy LLM': 0.0,
#    'Character Error Rate LLM': 9.090909090909092},
#   'tr_img_03035': {'Levenshtein Accuracy': 56.09756097560976,
#    'Word Accuracy': 63.63636363636363,
#    'Character Error Rate': 63.63636363636363,
#    'Levenshtein Accuracy LLM': 51.61290322580645,
#    'Word Accuracy LLM': 18.181818181818183,
#    'Character Error Rate LLM': 68.18181818181817},
#   'tr_img_03038': {'Levenshtein Accuracy': 78.57142857142857,
#    'Word Accuracy': 50.0,
#    'Character Error Rate': 21.428571428571427,
#    'Levenshtein Accuracy LLM': 78.57142857142857,
#    'Word Accuracy LLM': 50.0,
#    'Character Error Rate LLM': 21.428571428571427},
#   'tr_img_03039': {'Levenshtein Accuracy': 100.0,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 0.0,
#    'Levenshtein Accuracy LLM': 100.0,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 0.0},
#   'tr_img_03040': {'Levenshtein Accuracy': 13.725490196078427,
#    'Word Accuracy': 16.666666666666664,
#    'Character Error Rate': 86.27450980392157,
#    'Levenshtein Accuracy LLM': 11.764705882352944,
#    'Word Accuracy LLM': 8.333333333333332,
#    'Character Error Rate LLM': 88.23529411764706},
#   'tr_img_03044': {'Levenshtein Accuracy': 90.2439024390244,
#    'Word Accuracy': 50.0,
#    'Character Error Rate': 10.81081081081081,
#    'Levenshtein Accuracy LLM': 97.2972972972973,
#    'Word Accuracy LLM': 0.0,
#    'Character Error Rate LLM': 2.7027027027027026},
#   'tr_img_03051': {'Levenshtein Accuracy': 82.35294117647058,
#    'Word Accuracy': 77.77777777777779,
#    'Character Error Rate': 17.91044776119403,
#    'Levenshtein Accuracy LLM': 82.35294117647058,
#    'Word Accuracy LLM': 77.77777777777779,
#    'Character Error Rate LLM': 17.91044776119403},
#   'tr_img_03052': {'Levenshtein Accuracy': 100.0,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 0.0,
#    'Levenshtein Accuracy LLM': 100.0,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 0.0},
#   'tr_img_03053': {'Levenshtein Accuracy': 0.0,
#    'Word Accuracy': 0.0,
#    'Character Error Rate': 100.0,
#    'Levenshtein Accuracy LLM': 0.0,
#    'Word Accuracy LLM': 0.0,
#    'Character Error Rate LLM': 100.0},
#   'tr_img_03056': {'Levenshtein Accuracy': 33.82352941176471,
#    'Word Accuracy': 80.0,
#    'Character Error Rate': 71.875,
#    'Levenshtein Accuracy LLM': 33.333333333333336,
#    'Word Accuracy LLM': 80.0,
#    'Character Error Rate LLM': 68.75},
#   'tr_img_03058': {'Levenshtein Accuracy': 100.0,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 0.0,
#    'Levenshtein Accuracy LLM': 100.0,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 0.0},
#   'tr_img_03059': {'Levenshtein Accuracy': 94.73684210526316,
#    'Word Accuracy': 50.0,
#    'Character Error Rate': 5.263157894736842,
#    'Levenshtein Accuracy LLM': 80.0,
#    'Word Accuracy LLM': 0.0,
#    'Character Error Rate LLM': 21.052631578947366},
#   'tr_img_03060': {'Levenshtein Accuracy': 100.0,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 0.0,
#    'Levenshtein Accuracy LLM': 100.0,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 0.0},
#   'tr_img_03061': {'Levenshtein Accuracy': 40.90909090909091,
#    'Word Accuracy': 50.0,
#    'Character Error Rate': 59.09090909090909,
#    'Levenshtein Accuracy LLM': 40.90909090909091,
#    'Word Accuracy LLM': 75.0,
#    'Character Error Rate LLM': 63.63636363636363},
#   'tr_img_03063': {'Levenshtein Accuracy': 0.0,
#    'Word Accuracy': 0.0,
#    'Character Error Rate': 100.0,
#    'Levenshtein Accuracy LLM': 0.0,
#    'Word Accuracy LLM': 0.0,
#    'Character Error Rate LLM': 825.0},
#   'tr_img_03064': {'Levenshtein Accuracy': 100.0,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 0.0,
#    'Levenshtein Accuracy LLM': 80.0,
#    'Word Accuracy LLM': 0.0,
#    'Character Error Rate LLM': 20.0},
#   'tr_img_03066': {'Levenshtein Accuracy': 21.212121212121215,
#    'Word Accuracy': 0.0,
#    'Character Error Rate': 216.66666666666666,
#    'Levenshtein Accuracy LLM': 3.57142857142857,
#    'Word Accuracy LLM': 0.0,
#    'Character Error Rate LLM': 225.0},
#   'tr_img_03067': {'Levenshtein Accuracy': 82.85714285714285,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 17.142857142857142,
#    'Levenshtein Accuracy LLM': 76.31578947368422,
#    'Word Accuracy LLM': 80.0,
#    'Character Error Rate LLM': 25.71428571428571},
#   'tr_img_03068': {'Levenshtein Accuracy': 84.0,
#    'Word Accuracy': 66.66666666666666,
#    'Character Error Rate': 16.0,
#    'Levenshtein Accuracy LLM': 76.0,
#    'Word Accuracy LLM': 66.66666666666666,
#    'Character Error Rate LLM': 24.0},
#   'tr_img_03069': {'Levenshtein Accuracy': 100.0,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 0.0,
#    'Levenshtein Accuracy LLM': 100.0,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 0.0},
#   'tr_img_03070': {'Levenshtein Accuracy': 75.0,
#    'Word Accuracy': 33.33333333333333,
#    'Character Error Rate': 25.0,
#    'Levenshtein Accuracy LLM': 75.0,
#    'Word Accuracy LLM': 33.33333333333333,
#    'Character Error Rate LLM': 25.0},
#   'tr_img_03071': {'Levenshtein Accuracy': 19.999999999999996,
#    'Word Accuracy': 80.0,
#    'Character Error Rate': 80.0,
#    'Levenshtein Accuracy LLM': 35.55555555555555,
#    'Word Accuracy LLM': 40.0,
#    'Character Error Rate LLM': 64.44444444444444},
#   'tr_img_03072': {'Levenshtein Accuracy': 100.0,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 0.0,
#    'Levenshtein Accuracy LLM': 66.66666666666667,
#    'Word Accuracy LLM': 0.0,
#    'Character Error Rate LLM': 33.33333333333333},
#   'tr_img_03073': {'Levenshtein Accuracy': 95.45454545454545,
# ...
#    'Word Accuracy': 0.0,
#    'Character Error Rate': 100.0,
#    'Levenshtein Accuracy LLM': 7.14285714285714,
#    'Word Accuracy LLM': 0.0,
#    'Character Error Rate LLM': 92.85714285714286},
#   'tr_img_08037': {'Levenshtein Accuracy': 17.647058823529417,
#    'Word Accuracy': 0.0,
#    'Character Error Rate': 82.35294117647058,
#    'Levenshtein Accuracy LLM': 5.882352941176472,
#    'Word Accuracy LLM': 0.0,
#    'Character Error Rate LLM': 94.11764705882352},
#   'tr_img_08038': {'Levenshtein Accuracy': 0.0,
#    'Word Accuracy': 0.0,
#    'Character Error Rate': 100.0,
#    'Levenshtein Accuracy LLM': 0.0,
#    'Word Accuracy LLM': 0.0,
#    'Character Error Rate LLM': 825.0},
#   'tr_img_08039': {'Levenshtein Accuracy': 0.0,
#    'Word Accuracy': 0.0,
#    'Character Error Rate': 100.0,
#    'Levenshtein Accuracy LLM': 3.0303030303030276,
#    'Word Accuracy LLM': 0.0,
#    'Character Error Rate LLM': 228.57142857142856},
#   'tr_img_08040': {'Levenshtein Accuracy': 7.317073170731703,
#    'Word Accuracy': 0.0,
#    'Character Error Rate': 92.6829268292683,
#    'Levenshtein Accuracy LLM': 4.878048780487809,
#    'Word Accuracy LLM': 0.0,
#    'Character Error Rate LLM': 95.1219512195122},
#   'tr_img_08041': {'Levenshtein Accuracy': 9.375,
#    'Word Accuracy': 0.0,
#    'Character Error Rate': 111.53846153846155,
#    'Levenshtein Accuracy LLM': 9.375,
#    'Word Accuracy LLM': 0.0,
#    'Character Error Rate LLM': 111.53846153846155},
#   'tr_img_08042': {'Levenshtein Accuracy': 0.0,
#    'Word Accuracy': 0.0,
#    'Character Error Rate': 200.0,
#    'Levenshtein Accuracy LLM': 0.0,
#    'Word Accuracy LLM': 0.0,
#    'Character Error Rate LLM': 200.0},
#   'tr_img_08043': {'Levenshtein Accuracy': 0.0,
#    'Word Accuracy': 0.0,
#    'Character Error Rate': 100.0,
#    'Levenshtein Accuracy LLM': 0.0,
#    'Word Accuracy LLM': 0.0,
#    'Character Error Rate LLM': 100.0},
#   'tr_img_08044': {'Levenshtein Accuracy': 9.375,
#    'Word Accuracy': 0.0,
#    'Character Error Rate': 90.625,
#    'Levenshtein Accuracy LLM': 9.375,
#    'Word Accuracy LLM': 0.0,
#    'Character Error Rate LLM': 90.625},
#   'tr_img_08045': {'Levenshtein Accuracy': 31.707317073170728,
#    'Word Accuracy': 40.0,
#    'Character Error Rate': 107.6923076923077,
#    'Levenshtein Accuracy LLM': 46.15384615384615,
#    'Word Accuracy LLM': 40.0,
#    'Character Error Rate LLM': 53.84615384615385},
#   'tr_img_08046': {'Levenshtein Accuracy': 7.692307692307687,
#    'Word Accuracy': 0.0,
#    'Character Error Rate': 100.0,
#    'Levenshtein Accuracy LLM': 7.14285714285714,
#    'Word Accuracy LLM': 0.0,
#    'Character Error Rate LLM': 108.33333333333333},
#   'tr_img_08047': {'Levenshtein Accuracy': 8.108108108108103,
#    'Word Accuracy': 0.0,
#    'Character Error Rate': 91.8918918918919,
#    'Levenshtein Accuracy LLM': 5.405405405405405,
#    'Word Accuracy LLM': 0.0,
#    'Character Error Rate LLM': 94.5945945945946},
#   'tr_img_08048': {'Levenshtein Accuracy': 20.68965517241379,
#    'Word Accuracy': 25.0,
#    'Character Error Rate': 100.0,
#    'Levenshtein Accuracy LLM': 20.68965517241379,
#    'Word Accuracy LLM': 25.0,
#    'Character Error Rate LLM': 100.0},
#   'tr_img_08049': {'Levenshtein Accuracy': 0.0,
#    'Word Accuracy': 0.0,
#    'Character Error Rate': 100.0,
#    'Levenshtein Accuracy LLM': 0.0,
#    'Word Accuracy LLM': 0.0,
#    'Character Error Rate LLM': 100.0},
#   'tr_img_08050': {'Levenshtein Accuracy': 9.999999999999998,
#    'Word Accuracy': 0.0,
#    'Character Error Rate': 90.0,
#    'Levenshtein Accuracy LLM': 9.999999999999998,
#    'Word Accuracy LLM': 0.0,
#    'Character Error Rate LLM': 90.0}},
#  'Hindi': {'tr_img_09001': {'Levenshtein Accuracy': 100.0,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 0.0,
#    'Levenshtein Accuracy LLM': 92.0,
#    'Word Accuracy LLM': 50.0,
#    'Character Error Rate LLM': 8.695652173913043},
#   'tr_img_09002': {'Levenshtein Accuracy': 90.9090909090909,
#    'Word Accuracy': 66.66666666666666,
#    'Character Error Rate': 9.523809523809524,
#    'Levenshtein Accuracy LLM': 86.36363636363636,
#    'Word Accuracy LLM': 66.66666666666666,
#    'Character Error Rate LLM': 14.285714285714285},
#   'tr_img_09003': {'Levenshtein Accuracy': 100.0,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 0.0,
#    'Levenshtein Accuracy LLM': 100.0,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 0.0},
#   'tr_img_09004': {'Levenshtein Accuracy': 97.36842105263158,
#    'Word Accuracy': 83.33333333333334,
#    'Character Error Rate': 2.7027027027027026,
#    'Levenshtein Accuracy LLM': 100.0,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 0.0},
#   'tr_img_09005': {'Levenshtein Accuracy': 95.0,
#    'Word Accuracy': 50.0,
#    'Character Error Rate': 5.0,
#    'Levenshtein Accuracy LLM': 80.0,
#    'Word Accuracy LLM': 50.0,
#    'Character Error Rate LLM': 20.0},
#   'tr_img_09006': {'Levenshtein Accuracy': 98.07692307692307,
#    'Word Accuracy': 87.5,
#    'Character Error Rate': 1.9230769230769231,
#    'Levenshtein Accuracy LLM': 96.15384615384616,
#    'Word Accuracy LLM': 75.0,
#    'Character Error Rate LLM': 3.8461538461538463},
#   'tr_img_09007': {'Levenshtein Accuracy': 100.0,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 0.0,
#    'Levenshtein Accuracy LLM': 100.0,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 0.0},
#   'tr_img_09008': {'Levenshtein Accuracy': 94.28571428571428,
#    'Word Accuracy': 66.66666666666666,
#    'Character Error Rate': 5.714285714285714,
#    'Levenshtein Accuracy LLM': 94.28571428571428,
#    'Word Accuracy LLM': 66.66666666666666,
#    'Character Error Rate LLM': 5.714285714285714},
#   'tr_img_09009': {'Levenshtein Accuracy': 91.66666666666666,
#    'Word Accuracy': 50.0,
#    'Character Error Rate': 8.333333333333332,
#    'Levenshtein Accuracy LLM': 88.88888888888889,
#    'Word Accuracy LLM': 50.0,
#    'Character Error Rate LLM': 11.11111111111111},
#   'tr_img_09010': {'Levenshtein Accuracy': 90.47619047619048,
#    'Word Accuracy': 50.0,
#    'Character Error Rate': 9.523809523809524,
#    'Levenshtein Accuracy LLM': 90.47619047619048,
#    'Word Accuracy LLM': 50.0,
#    'Character Error Rate LLM': 9.523809523809524},
#   'tr_img_09011': {'Levenshtein Accuracy': 66.66666666666667,
#    'Word Accuracy': 0.0,
#    'Character Error Rate': 33.33333333333333,
#    'Levenshtein Accuracy LLM': 66.66666666666667,
#    'Word Accuracy LLM': 0.0,
#    'Character Error Rate LLM': 33.33333333333333},
#   'tr_img_09012': {'Levenshtein Accuracy': 95.23809523809523,
#    'Word Accuracy': 75.0,
#    'Character Error Rate': 4.761904761904762,
#    'Levenshtein Accuracy LLM': 95.23809523809523,
#    'Word Accuracy LLM': 75.0,
#    'Character Error Rate LLM': 4.761904761904762},
#   'tr_img_09013': {'Levenshtein Accuracy': 96.2962962962963,
#    'Word Accuracy': 80.0,
#    'Character Error Rate': 3.7037037037037033,
#    'Levenshtein Accuracy LLM': 92.5925925925926,
#    'Word Accuracy LLM': 60.0,
#    'Character Error Rate LLM': 7.4074074074074066},
#   'tr_img_09014': {'Levenshtein Accuracy': 100.0,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 0.0,
#    'Levenshtein Accuracy LLM': 100.0,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 0.0},
#   'tr_img_09015': {'Levenshtein Accuracy': 81.13207547169812,
#    'Word Accuracy': 60.0,
#    'Character Error Rate': 18.867924528301888,
#    'Levenshtein Accuracy LLM': 74.54545454545455,
#    'Word Accuracy LLM': 40.0,
#    'Character Error Rate LLM': 26.41509433962264},
#   'tr_img_09016': {'Levenshtein Accuracy': 100.0,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 0.0,
#    'Levenshtein Accuracy LLM': 5.882352941176472,
#    'Word Accuracy LLM': 0.0,
#    'Character Error Rate LLM': 94.11764705882352},
#   'tr_img_09017': {'Levenshtein Accuracy': 100.0,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 0.0,
#    'Levenshtein Accuracy LLM': 100.0,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 0.0},
#   'tr_img_09018': {'Levenshtein Accuracy': 87.87878787878788,
#    'Word Accuracy': 50.0,
#    'Character Error Rate': 12.121212121212121,
#    'Levenshtein Accuracy LLM': 87.87878787878788,
#    'Word Accuracy LLM': 50.0,
#    'Character Error Rate LLM': 12.121212121212121},
#   'tr_img_09019': {'Levenshtein Accuracy': 100.0,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 0.0,
#    'Levenshtein Accuracy LLM': 100.0,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 0.0},
#   'tr_img_09020': {'Levenshtein Accuracy': 67.16417910447761,
#    'Word Accuracy': 80.0,
#    'Character Error Rate': 33.33333333333333,
#    'Levenshtein Accuracy LLM': 68.18181818181819,
#    'Word Accuracy LLM': 70.0,
#    'Character Error Rate LLM': 31.818181818181817},
#   'tr_img_09021': {'Levenshtein Accuracy': 93.33333333333333,
#    'Word Accuracy': 75.0,
#    'Character Error Rate': 6.666666666666667,
#    'Levenshtein Accuracy LLM': 74.28571428571429,
#    'Word Accuracy LLM': 50.0,
#    'Character Error Rate LLM': 30.0},
#   'tr_img_09022': {'Levenshtein Accuracy': 28.888888888888886,
#    'Word Accuracy': 28.57142857142857,
#    'Character Error Rate': 71.11111111111111,
#    'Levenshtein Accuracy LLM': 26.66666666666667,
#    'Word Accuracy LLM': 14.285714285714285,
#    'Character Error Rate LLM': 73.33333333333333},
#   'tr_img_09023': {'Levenshtein Accuracy': 95.23809523809523,
#    'Word Accuracy': 75.0,
#    'Character Error Rate': 4.761904761904762,
#    'Levenshtein Accuracy LLM': 95.23809523809523,
#    'Word Accuracy LLM': 75.0,
#    'Character Error Rate LLM': 4.761904761904762},
#   'tr_img_09024': {'Levenshtein Accuracy': 12.5,
#    'Word Accuracy': 33.33333333333333,
#    'Character Error Rate': 87.5,
#    'Levenshtein Accuracy LLM': 12.5,
#    'Word Accuracy LLM': 33.33333333333333,
#    'Character Error Rate LLM': 87.5},
#   'tr_img_09025': {'Levenshtein Accuracy': 100.0,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 0.0,
#    'Levenshtein Accuracy LLM': 100.0,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 0.0},
#   'tr_img_09026': {'Levenshtein Accuracy': 76.92307692307692,
#    'Word Accuracy': 50.0,
#    'Character Error Rate': 27.27272727272727,
#    'Levenshtein Accuracy LLM': 58.33333333333333,
#    'Word Accuracy LLM': 50.0,
#    'Character Error Rate LLM': 45.45454545454545},
#   'tr_img_09027': {'Levenshtein Accuracy': 95.91836734693877,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 4.25531914893617,
#    'Levenshtein Accuracy LLM': 94.0,
#    'Word Accuracy LLM': 57.14285714285714,
#    'Character Error Rate LLM': 6.382978723404255},
#   'tr_img_09028': {'Levenshtein Accuracy': 83.6734693877551,
#    'Word Accuracy': 85.71428571428571,
#    'Character Error Rate': 19.047619047619047,
#    'Levenshtein Accuracy LLM': 81.63265306122449,
#    'Word Accuracy LLM': 71.42857142857143,
#    'Character Error Rate LLM': 21.428571428571427},
#   'tr_img_09029': {'Levenshtein Accuracy': 100.0,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 0.0,
#    'Levenshtein Accuracy LLM': 100.0,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 0.0},
#   'tr_img_09031': {'Levenshtein Accuracy': 84.61538461538461,
#    'Word Accuracy': 50.0,
#    'Character Error Rate': 15.384615384615385,
#    'Levenshtein Accuracy LLM': 84.61538461538461,
#    'Word Accuracy LLM': 50.0,
#    'Character Error Rate LLM': 15.384615384615385},
#   'tr_img_09033': {'Levenshtein Accuracy': 88.0,
#    'Word Accuracy': 66.66666666666666,
#    'Character Error Rate': 12.0,
#    'Levenshtein Accuracy LLM': 88.0,
#    'Word Accuracy LLM': 66.66666666666666,
#    'Character Error Rate LLM': 12.0},
#   'tr_img_09034': {'Levenshtein Accuracy': 100.0,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 0.0,
#    'Levenshtein Accuracy LLM': 100.0,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 0.0},
#   'tr_img_09035': {'Levenshtein Accuracy': 100.0,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 0.0,
#    'Levenshtein Accuracy LLM': 100.0,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 0.0},
#   'tr_img_09036': {'Levenshtein Accuracy': 85.71428571428572,
#    'Word Accuracy': 50.0,
#    'Character Error Rate': 14.285714285714285,
#    'Levenshtein Accuracy LLM': 85.71428571428572,
#    'Word Accuracy LLM': 50.0,
#    'Character Error Rate LLM': 14.285714285714285},
#   'tr_img_09038': {'Levenshtein Accuracy': 100.0,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 0.0,
#    'Levenshtein Accuracy LLM': 100.0,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 0.0},
#   'tr_img_09039': {'Levenshtein Accuracy': 72.72727272727273,
#    'Word Accuracy': 0.0,
#    'Character Error Rate': 27.27272727272727,
#    'Levenshtein Accuracy LLM': 81.81818181818181,
#    'Word Accuracy LLM': 50.0,
#    'Character Error Rate LLM': 18.181818181818183},
#   'tr_img_09040': {'Levenshtein Accuracy': 94.44444444444444,
#    'Word Accuracy': 50.0,
#    'Character Error Rate': 5.555555555555555,
#    'Levenshtein Accuracy LLM': 94.44444444444444,
#    'Word Accuracy LLM': 50.0,
#    'Character Error Rate LLM': 5.555555555555555},
#   'tr_img_09041': {'Levenshtein Accuracy': 0.0,
#    'Word Accuracy': 0.0,
#    'Character Error Rate': 100.0,
#    'Levenshtein Accuracy LLM': 3.0303030303030276,
#    'Word Accuracy LLM': 0.0,
#    'Character Error Rate LLM': 457.1428571428571},
#   'tr_img_09042': {'Levenshtein Accuracy': 46.34146341463414,
#    'Word Accuracy': 57.14285714285714,
#    'Character Error Rate': 53.65853658536586,
#    'Levenshtein Accuracy LLM': 48.78048780487805,
#    'Word Accuracy LLM': 57.14285714285714,
#    'Character Error Rate LLM': 51.21951219512195},
#   'tr_img_09043': {'Levenshtein Accuracy': 100.0,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 0.0,
#    'Levenshtein Accuracy LLM': 100.0,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 0.0},
#   'tr_img_09044': {'Levenshtein Accuracy': 100.0,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 0.0,
#    'Levenshtein Accuracy LLM': 100.0,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 0.0},
#   'tr_img_09045': {'Levenshtein Accuracy': 95.23809523809523,
#    'Word Accuracy': 66.66666666666666,
#    'Character Error Rate': 5.0,
#    'Levenshtein Accuracy LLM': 79.16666666666666,
#    'Word Accuracy LLM': 50.0,
#    'Character Error Rate LLM': 25.0},
#   'tr_img_09046': {'Levenshtein Accuracy': 16.666666666666664,
#    'Word Accuracy': 0.0,
#    'Character Error Rate': 83.33333333333334,
#    'Levenshtein Accuracy LLM': 16.666666666666664,
#    'Word Accuracy LLM': 0.0,
#    'Character Error Rate LLM': 83.33333333333334},
#   'tr_img_09047': {'Levenshtein Accuracy': 100.0,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 0.0,
#    'Levenshtein Accuracy LLM': 95.65217391304348,
#    'Word Accuracy LLM': 75.0,
#    'Character Error Rate LLM': 4.3478260869565215},
#   'tr_img_09048': {'Levenshtein Accuracy': 87.5,
#    'Word Accuracy': 40.0,
#    'Character Error Rate': 12.5,
#    'Levenshtein Accuracy LLM': 87.5,
#    'Word Accuracy LLM': 40.0,
#    'Character Error Rate LLM': 12.5},
#   'tr_img_09049': {'Levenshtein Accuracy': 100.0,
#    'Word Accuracy': 100.0,
#    'Character Error Rate': 0.0,
#    'Levenshtein Accuracy LLM': 95.65217391304348,
#    'Word Accuracy LLM': 33.33333333333333,
#    'Character Error Rate LLM': 4.3478260869565215},
#   'tr_img_09050': {'Levenshtein Accuracy': 72.72727272727273,
#    'Word Accuracy': 50.0,
#    'Character Error Rate': 27.27272727272727,
#    'Levenshtein Accuracy LLM': 72.72727272727273,
#    'Word Accuracy LLM': 50.0,
#    'Character Error Rate LLM': 27.27272727272727},
#   'tr_img_09051': {'Levenshtein Accuracy': 82.35294117647058,
#    'Word Accuracy': 83.33333333333334,
#    'Character Error Rate': 17.647058823529413,
#    'Levenshtein Accuracy LLM': 88.23529411764706,
#    'Word Accuracy LLM': 100.0,
#    'Character Error Rate LLM': 11.76470588235294},
#   'tr_img_09052': {'Levenshtein Accuracy': 80.0,
#    'Word Accuracy': 50.0,
#    'Character Error Rate': 20.0,
#    'Levenshtein Accuracy LLM': 80.0,
#    'Word Accuracy LLM': 50.0,
#    'Character Error Rate LLM': 20.0},
#   'tr_img_09053': {'Levenshtein Accuracy': 86.8421052631579,
#    'Word Accuracy': 40.0,
#    'Character Error Rate': 13.157894736842104,
#    'Levenshtein Accuracy LLM': 86.8421052631579,
#    'Word Accuracy LLM': 40.0,
#    'Character Error Rate LLM': 13.157894736842104}}}

# %%
# Esempio di dati delle metriche
evaluations = {
    "Azure OCR": Azure_Evaluation,
    #"AWS Textract": Aws_Evaluation,
    "OCR.space": OcrSpace_Evaluation,
    #"Tesseract": Tesseract_Evaluation,
    "Google Cloud Vision API": OcrCloudVision_Evaluation
}

evaluate_all_metrics(evaluations, alpha=0.01, beta=1, gamma=0.01,hard_languages=hard_languages)
# Out:
# Processing evaluations for Arabic...
#
# Azure OCR - Arabic: Average Score: 77.05, with LLM: 68.83
# OCR.space - Arabic: Average Score: 62.15, with LLM: 57.58
# Google Cloud Vision API - Arabic: Average Score: 71.76, with LLM: 62.32
# Results for Arabic saved to Arabic_ocr_evaluation_results.xlsx
#
# Processing evaluations for Chinese...
#
# Azure OCR - Chinese: Average Score: 69.33, with LLM: 52.83
# OCR.space - Chinese: Average Score: 45.43, with LLM: 40.63
# Google Cloud Vision API - Chinese: Average Score: 63.66, with LLM: 55.36
# Results for Chinese saved to Chinese_ocr_evaluation_results.xlsx
#
# Processing evaluations for Korean...
#
# Azure OCR - Korean: Average Score: 65.67, with LLM: 61.76
# OCR.space - Korean: Average Score: 60.15, with LLM: 56.14
# Google Cloud Vision API - Korean: Average Score: 64.17, with LLM: 59.85
# Results for Korean saved to Korean_ocr_evaluation_results.xlsx
#
# Processing evaluations for Japanese...
#
# Azure OCR - Japanese: Average Score: 67.13, with LLM: 53.71
# OCR.space - Japanese: Average Score: 30.69, with LLM: 30.93
# Google Cloud Vision API - Japanese: Average Score: 66.42, with LLM: 57.00
# Results for Japanese saved to Japanese_ocr_evaluation_results.xlsx
#
# Processing evaluations for Hindi...
#
# Azure OCR - Hindi: Average Score: 69.71, with LLM: 62.89
# OCR.space - Hindi: Average Score: 1.94, with LLM: 1.95
# Google Cloud Vision API - Hindi: Average Score: 77.99, with LLM: 68.71
# Results for Hindi saved to Hindi_ocr_evaluation_results.xlsx
# {'Arabic': {'Best API': 'Azure OCR', 'Best Score': 77.05279453007532},
#  'Chinese': {'Best API': 'Azure OCR', 'Best Score': 69.3299715170022},
#  'Korean': {'Best API': 'Azure OCR', 'Best Score': 65.66621922905455},
#  'Japanese': {'Best API': 'Azure OCR', 'Best Score': 67.1251686885107},
#  'Hindi': {'Best API': 'Google Cloud Vision API',
#   'Best Score': 77.98745986681595}}
